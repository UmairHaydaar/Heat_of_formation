# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn import preprocessing
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, r2_score,mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2024-10-06 13:37:03.502534: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dataset = pd.read_csv("data_for_traing_ml_models.csv")

#####################

'''
4-feature dataset is run on Simple Linear Regression, LASSO, Ridge, Random Forest and Neural Network models for the prediction of Heat of Formation of MXenes.
'''
# Out:
# '\n4-feature dataset is run on Simple Linear Regression, LASSO, Ridge, Random Forest and Neural Network models for the prediction of Heat of Formation of MXenes.\n'

# %%
# take a look at the dataset
dataset.head()
dataset.describe()
# Out:
#        Work_function  Heat_of_formation  Energy_above_convex_hull   Length(x)  \
# count     275.000000         275.000000                275.000000  275.000000
# mean        4.264700          -1.062837                  0.315639  311.577091
# std         1.530484           0.835387                  0.228956   20.841980
# min         1.347678          -2.984132                  0.000000  262.100000
# 25%         2.792242          -1.646810                  0.162571  294.700000
# 50%         4.537063          -1.079087                  0.268825  312.500000
# 75%         5.349280          -0.483631                  0.424251  324.000000
# max         7.271891           0.957153                  1.138551  378.300000
#
#        Radius_of_orbital_of_metal  Radius_of_orbital_of_support  \
# count                  275.000000                    275.000000
# mean                    65.518545                     54.219636
# std                     16.428133                      5.409809
# min                     38.900000                     48.800000
# 25%                     48.900000                     48.800000
# 50%                     74.600000                     59.600000
# 75%                     79.000000                     59.600000
# max                     86.500000                     59.600000
#
#        Radius_of_orbital_of_termination  Ionisation_potential_of_metal  \
# count                        275.000000                     275.000000
# mean                          45.983636                       6.980777
# std                           13.987596                       0.518915
# min                           36.000000                       6.217000
# 25%                           38.900000                       6.633900
# 50%                           41.400000                       6.825000
# 75%                           41.400000                       7.264100
# max                           86.500000                       7.980000
#
#        Ionisation_potential_of_support  Ionisation_potential_of_termination  \
# count                       275.000000                           275.000000
# mean                         12.891248                            12.719608
# std                           1.639873                             3.765861
# min                          11.260300                             6.217000
# 25%                          11.260300                             7.980000
# 50%                          11.260300                            13.017000
# 75%                          14.534100                            13.618000
# max                          14.534100                            17.422800
#
#        Electronegativity_of_metal  Electronegativity_of_support  \
# count                  275.000000                    275.000000
# mean                     1.601527                      2.794109
# std                      0.333816                      0.245445
# min                      1.220000                      2.550000
# 25%                      1.330000                      2.550000
# 50%                      1.540000                      2.550000
# 75%                      1.630000                      3.040000
# max                      2.360000                      3.040000
#
#        Electronegativity_of_termination  Electron_affinity_of_metal  \
# count                        275.000000                  275.000000
# mean                           2.951018                    0.394964
# std                            0.903641                    0.364981
# min                            1.220000                   -0.500000
# 25%                            2.360000                    0.189000
# 50%                            2.820000                    0.323000
# 75%                            3.440000                    0.749000
# max                            3.980000                    0.894000
#
#        Electron_affinity_of_support  Electron_affinity_of_termination
# count                    275.000000                        275.000000
# mean                       0.598422                          1.755294
# std                        0.667210                          1.099077
# min                       -0.070000                         -0.500000
# 25%                       -0.070000                          0.894000
# 50%                        1.262000                          1.439000
# 75%                        1.262000                          1.827000
# max                        1.262000                          3.401000

# %%
cdf = dataset[['Work_function','Heat_of_formation','Energy_above_convex_hull','Length(x)','Radius_of_orbital_of_metal','Radius_of_orbital_of_support','Radius_of_orbital_of_termination','Ionisation_potential_of_metal','Ionisation_potential_of_support','Ionisation_potential_of_termination','Electronegativity_of_metal','Electronegativity_of_support','Electronegativity_of_termination','Electron_affinity_of_metal','Electron_affinity_of_support','Electron_affinity_of_termination']]
cdf.head(9)
# Out:
#    Work_function  Heat_of_formation  Energy_above_convex_hull  Length(x)  \
# 0       2.271378          -1.345952                  0.242880      330.4
# 1       1.588009          -1.199954                  0.452744      335.0
# 2       2.209840          -0.317344                  0.473693      290.6
# 3       2.463148          -0.594739                  0.327053      285.0
# 4       2.329750          -1.597694                  0.163033      298.9
# 5       2.429486          -1.645322                  0.315790      320.4
# 6       6.244289          -0.755420                  0.290092      293.1
# 7       4.424606          -1.265524                  0.269073      316.7
# 8       4.468438          -1.715968                  0.168985      348.9
#
#    Radius_of_orbital_of_metal  Radius_of_orbital_of_support  \
# 0                        82.9                          59.6
# 1                        53.9                          59.6
# 2                        74.6                          59.6
# 3                        70.2                          48.8
# 4                        48.9                          48.8
# 5                        79.0                          48.8
# 6                        38.9                          59.6
# 7                        78.4                          59.6
# 8                        86.5                          59.6
#
#    Radius_of_orbital_of_termination  Ionisation_potential_of_metal  \
# 0                              41.4                         6.8250
# 1                              41.4                         6.5614
# 2                              41.4                         7.9800
# 3                              41.4                         7.0942
# 4                              41.4                         6.8282
# 5                              41.4                         6.6339
# 6                              36.0                         7.4340
# 7                              36.0                         7.8900
# 8                              36.0                         6.2170
#
#    Ionisation_potential_of_support  Ionisation_potential_of_termination  \
# 0                          11.2603                              13.0170
# 1                          11.2603                              13.0170
# 2                          11.2603                              13.0170
# 3                          14.5341                              13.0170
# 4                          14.5341                              13.0170
# 5                          14.5341                              13.0170
# 6                          11.2603                              17.4228
# 7                          11.2603                              17.4228
# 8                          11.2603                              17.4228
#
#    Electronegativity_of_metal  Electronegativity_of_support  \
# 0                        1.30                          2.55
# 1                        1.36                          2.55
# 2                        2.36                          2.55
# 3                        2.16                          3.04
# 4                        1.54                          3.04
# 5                        1.33                          3.04
# 6                        1.55                          2.55
# 7                        1.50                          2.55
# 8                        1.22                          2.55
#
#    Electronegativity_of_termination  Electron_affinity_of_metal  \
# 0                              2.82                       0.178
# 1                              2.82                       0.189
# 2                              2.82                       0.816
# 3                              2.82                       0.749
# 4                              2.82                       0.087
# 5                              2.82                       0.427
# 6                              3.98                      -0.500
# 7                              3.98                       0.323
# 8                              3.98                       0.308
#
#    Electron_affinity_of_support  Electron_affinity_of_termination
# 0                         1.262                             1.827
# 1                         1.262                             1.827
# 2                         1.262                             1.827
# 3                        -0.070                             1.827
# 4                        -0.070                             1.827
# 5                        -0.070                             1.827
# 6                         1.262                             3.401
# 7                         1.262                             3.401
# 8                         1.262                             3.401

# %%
###################### Simple Linear Regression

regr = LinearRegression()

# Assuming 'HoF', 'E_Hull', 'Length(x)', ..., are your features
features = [ 'r-(M)', 'r-(T)', 'IP(X)',  'EN(T)' ]

features = ['Radius_of_orbital_of_metal','Radius_of_orbital_of_termination','Ionisation_potential_of_support','Electronegativity_of_termination']
target = ['Heat_of_formation']

# Split the data into train and test sets
train, test = train_test_split(dataset, test_size=0.2, random_state=42)

# Train set
train_x = np.asanyarray(train[features])
train_y = np.asanyarray(train[target])

# Test set
test_x = np.asanyarray(test[features])
test_y = np.asanyarray(test[target])

# Create and train the Linear Regression model
regr.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat = regr.predict(train_x)
test_y_hat = regr.predict(test_x)

# Calculate MSE, MAE, and R2 for the train set
train_mse = mean_squared_error(train_y, train_y_hat)
train_mae = mean_absolute_error(train_y, train_y_hat)
train_r2 = r2_score(train_y, train_y_hat)

# Calculate MSE, MAE, and R2 for the test set
test_mse = mean_squared_error(test_y, test_y_hat)
test_mae = mean_absolute_error(test_y, test_y_hat)
test_r2 = r2_score(test_y, test_y_hat)

# Print the results
print('Linear Regression\n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse)
print("MAE: %.2f" % train_mae)
print("R2 Score: %.2f" % train_r2)
print('LinearRegression\n')
print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse)
print("MAE: %.2f" % test_mae)
print("R2 Score: %.2f" % test_r2)
# Out:
# Linear Regression
#
# Train set metrics:
# MAE: 0.48
# R2 Score: 0.46
# LinearRegression
#
#
# Test set metrics:
# MAE: 0.50
# R2 Score: 0.56

# %%
####################### LASSO Regression


# Initialize LASSO model
regr1 = Lasso()
# Create and train the LASSO Regression model
regr1.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat1 = regr1.predict(train_x)
test_y_hat1 = regr1.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse1 = mean_squared_error(train_y, train_y_hat1)
train_mae1 = mean_absolute_error(train_y, train_y_hat1)
train_r2_1 = r2_score(train_y, train_y_hat1)

# Calculate MSE, MAE, and R2 for the test set
test_mse1 = mean_squared_error(test_y, test_y_hat1)
test_mae1 = mean_absolute_error(test_y, test_y_hat1)
test_r2_1 = r2_score(test_y, test_y_hat1)

# Print the results
print('LASSO Regression')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse1)
print("MAE: %.2f" % train_mae1)
print("R2 Score: %.2f" % train_r2_1)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse1)
print("MAE: %.2f" % test_mae1)
print("R2 Score: %.2f" % test_r2_1)
# Out:
# LASSO Regression
# Train set metrics:
# MAE: 0.54
# R2 Score: 0.31
#
# Test set metrics:
# MAE: 0.58
# R2 Score: 0.37

# %%
####################### Ridge Regression



# Initialize Ridge Regression
regr2 = Ridge()
# Create and train the Ridge Regression model
regr2.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat2 = regr2.predict(train_x)
test_y_hat2 = regr2.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse2 = mean_squared_error(train_y, train_y_hat2)
train_mae2 = mean_absolute_error(train_y, train_y_hat2)
train_r2_2 = r2_score(train_y, train_y_hat2)

# Calculate MSE, MAE, and R2 for the test set
test_mse2 = mean_squared_error(test_y, test_y_hat2)
test_mae2 = mean_absolute_error(test_y, test_y_hat2)
test_r2_2 = r2_score(test_y, test_y_hat2)

# Print the results
print('Ridge Regression\n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse2)
print("MAE: %.2f" % train_mae2)
print("R2 Score: %.2f" % train_r2_2)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse2)
print("MAE: %.2f" % test_mae2)
print("R2 Score: %.2f" % test_r2_2)
# Out:
# Ridge Regression
#
# Train set metrics:
# MAE: 0.48
# R2 Score: 0.46
#
# Test set metrics:
# MAE: 0.50
# R2 Score: 0.56

# %%
###################### Random Forest Regression



# Initialize Random Forest Regression
regr3 = RandomForestRegressor()
# Create and train the Random Forest Regression model
regr3.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat3 = regr3.predict(train_x)
test_y_hat3 = regr3.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse3 = mean_squared_error(train_y, train_y_hat3)
train_mae3 = mean_absolute_error(train_y, train_y_hat3)
train_r2_3 = r2_score(train_y, train_y_hat3)

# Calculate MSE, MAE, and R2 for the test set
test_mse3 = mean_squared_error(test_y, test_y_hat3)
test_mae3 = mean_absolute_error(test_y, test_y_hat3)
test_r2_3 = r2_score(test_y, test_y_hat3)

# Print the results
print('Random Forest Regression \n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse3)
print("MAE: %.2f" % train_mae3)
print("R2 Score: %.2f" % train_r2_3)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse3)
print("MAE: %.2f" % test_mae3)
print("R2 Score: %.2f" % test_r2_3)
# Out:
# Random Forest Regression
#
# Train set metrics:
# MAE: 0.15
# R2 Score: 0.94
#
# Test set metrics:
# MAE: 0.21
# R2 Score: 0.91
# /home/azaan/anaconda3/envs/data_science/lib/python3.9/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %% [markdown]
# ################## Neural Network Regression

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import  Adamax
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization

# Assuming 'dataset' is already loaded
dataset_columns = dataset.columns
columns_to_exclude = ['Formula', 'M', 'X', 'T', 'Work_function', 'Heat_of_formation', 'Energy_above_convex_hull', 'Length(x)','Radius_of_orbital_of_support','Electron_affinity_of_termination','Electronegativity_of_support','Ionisation_potential_of_termination','Electron_affinity_of_support','Electron_affinity_of_metal','Electronegativity_of_metal','Ionisation_potential_of_metal']

# Preprocess the data
predictors = dataset.drop(columns=columns_to_exclude)
target = dataset['Heat_of_formation']
predictors_norm = (predictors - predictors.mean()) / predictors.std()

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.2, random_state=42)

# Get the number of input features
n_cols = predictors_norm.shape[1]

def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(512, activation='relu', input_shape=(n_cols,), kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(256, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu', kernel_regularizer='l2'))
    model.add(Dense(1))
    optimizer = Adamax(learning_rate=0.002)
    model.compile(optimizer=optimizer, loss='mae')
    return model


# Build the model
model = regression_model()

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model
model.fit(X_train, y_train, batch_size=32, validation_split=0.2, epochs=600, verbose=1, callbacks=[early_stopping])

# Make predictions on the training set
train_predictions = model.predict(X_train)

# Make predictions on the testing set
test_predictions = model.predict(X_test)

# Calculate R2 score for training and testing sets
r2_train = r2_score(y_train, train_predictions)
r2_test = r2_score(y_test, test_predictions)

# Calculate MAE for training and testing sets
mae_train = mean_absolute_error(y_train, train_predictions)
mae_test = mean_absolute_error(y_test, test_predictions)

# Print the results
print(f'Training R2 Score: {r2_train}')
print(f'Testing R2 Score: {r2_test}')
print(f'Training Mean Absolute Error: {mae_train}')
print(f'Testing Mean Absolute Error: {mae_test}')
# Out:
# /home/azaan/anaconda3/envs/data_science/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-10-06 13:37:06.415621: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:37:06.422354: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:37:06.422650: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:37:06.423985: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:37:06.424564: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:37:06.425744: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:37:06.473359: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:37:06.473680: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:37:06.473903: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:37:06.474073: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 212 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 960M, pci bus id: 0000:01:00.0, compute capability: 5.0
# Epoch 1/600
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728203829.910062  278575 service.cc:145] XLA service 0x7339540059d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728203829.910114  278575 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 960M, Compute Capability 5.0
# 2024-10-06 13:37:10.029665: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-06 13:37:10.300832: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 50s 10s/step - loss: 7.1451
# I0000 00:00:1728203836.847327  278575 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - loss: 7.1517 - val_loss: 7.0933
# Epoch 2/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9029 - val_loss: 6.8927
# Epoch 3/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6345 - val_loss: 6.7535
# Epoch 4/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4043 - val_loss: 6.6287
# Epoch 5/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3380 - val_loss: 6.5346
# Epoch 6/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2427 - val_loss: 6.4131
# Epoch 7/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2098 - val_loss: 6.3111
# Epoch 8/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0934 - val_loss: 6.2135
# Epoch 9/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9898 - val_loss: 6.1163
# Epoch 10/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8850 - val_loss: 6.0205
# Epoch 11/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8226 - val_loss: 5.9267
# Epoch 12/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6867 - val_loss: 5.8609
# Epoch 13/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6529 - val_loss: 5.7949
# Epoch 14/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5857 - val_loss: 5.7333
# Epoch 15/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4846 - val_loss: 5.6800
# Epoch 16/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3856 - val_loss: 5.6001
# Epoch 17/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4097 - val_loss: 5.5025
# Epoch 18/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2532 - val_loss: 5.4244
# Epoch 19/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2223 - val_loss: 5.3580
# Epoch 20/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.1438 - val_loss: 5.2972
# Epoch 21/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0574 - val_loss: 5.2416
# Epoch 22/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0190 - val_loss: 5.1805
# Epoch 23/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9816 - val_loss: 5.1273
# Epoch 24/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9210 - val_loss: 5.0625
# Epoch 25/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9180 - val_loss: 5.0081
# Epoch 26/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7878 - val_loss: 4.9330
# Epoch 27/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7422 - val_loss: 4.8735
# Epoch 28/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7014 - val_loss: 4.8267
# Epoch 29/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7060 - val_loss: 4.7635
# Epoch 30/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.6038 - val_loss: 4.6984
# Epoch 31/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5435 - val_loss: 4.6441
# Epoch 32/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4611 - val_loss: 4.5985
# Epoch 33/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4249 - val_loss: 4.5523
# Epoch 34/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4405 - val_loss: 4.4992
# Epoch 35/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2963 - val_loss: 4.4374
# Epoch 36/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2991 - val_loss: 4.3891
# Epoch 37/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2152 - val_loss: 4.3429
# Epoch 38/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.1577 - val_loss: 4.2891
# Epoch 39/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1585 - val_loss: 4.2303
# Epoch 40/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0721 - val_loss: 4.1798
# Epoch 41/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0725 - val_loss: 4.1275
# Epoch 42/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0113 - val_loss: 4.0870
# Epoch 43/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9368 - val_loss: 4.0474
# Epoch 44/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8978 - val_loss: 3.9848
# Epoch 45/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8684 - val_loss: 3.9306
# Epoch 46/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8584 - val_loss: 3.8981
# Epoch 47/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8006 - val_loss: 3.8614
# Epoch 48/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6941 - val_loss: 3.8047
# Epoch 49/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7446 - val_loss: 3.7547
# Epoch 50/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6445 - val_loss: 3.6991
# Epoch 51/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6345 - val_loss: 3.6581
# Epoch 52/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5776 - val_loss: 3.6216
# Epoch 53/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5632 - val_loss: 3.5783
# Epoch 54/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5340 - val_loss: 3.5499
# Epoch 55/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4473 - val_loss: 3.5266
# Epoch 56/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4400 - val_loss: 3.4890
# Epoch 57/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3910 - val_loss: 3.4483
# Epoch 58/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3804 - val_loss: 3.4251
# Epoch 59/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2659 - val_loss: 3.4003
# Epoch 60/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2608 - val_loss: 3.3311
# Epoch 61/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2294 - val_loss: 3.2683
# Epoch 62/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2248 - val_loss: 3.2450
# Epoch 63/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1828 - val_loss: 3.2118
# Epoch 64/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1371 - val_loss: 3.1780
# Epoch 65/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1429 - val_loss: 3.1339
# Epoch 66/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0258 - val_loss: 3.0971
# Epoch 67/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0258 - val_loss: 3.0598
# Epoch 68/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9789 - val_loss: 3.0572
# Epoch 69/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9807 - val_loss: 3.0244
# Epoch 70/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9525 - val_loss: 2.9662
# Epoch 71/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8616 - val_loss: 2.9094
# Epoch 72/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8753 - val_loss: 2.8634
# Epoch 73/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8405 - val_loss: 2.8640
# Epoch 74/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7930 - val_loss: 2.8554
# Epoch 75/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8014 - val_loss: 2.8118
# Epoch 76/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7161 - val_loss: 2.7867
# Epoch 77/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6972 - val_loss: 2.7705
# Epoch 78/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7110 - val_loss: 2.7170
# Epoch 79/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6938 - val_loss: 2.6877
# Epoch 80/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6713 - val_loss: 2.6674
# Epoch 81/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6097 - val_loss: 2.6393
# Epoch 82/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6342 - val_loss: 2.5689
# Epoch 83/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5244 - val_loss: 2.5336
# Epoch 84/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4956 - val_loss: 2.4996
# Epoch 85/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4587 - val_loss: 2.4765
# Epoch 86/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5052 - val_loss: 2.4516
# Epoch 87/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3875 - val_loss: 2.4211
# Epoch 88/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4230 - val_loss: 2.3928
# Epoch 89/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3818 - val_loss: 2.3598
# Epoch 90/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3747 - val_loss: 2.3165
# Epoch 91/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3378 - val_loss: 2.2784
# Epoch 92/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3167 - val_loss: 2.2649
# Epoch 93/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2932 - val_loss: 2.2486
# Epoch 94/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2588 - val_loss: 2.2387
# Epoch 95/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2294 - val_loss: 2.2235
# Epoch 96/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2100 - val_loss: 2.1904
# Epoch 97/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1956 - val_loss: 2.1530
# Epoch 98/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1630 - val_loss: 2.1184
# Epoch 99/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1109 - val_loss: 2.0872
# Epoch 100/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1377 - val_loss: 2.0519
# Epoch 101/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1219 - val_loss: 2.0259
# Epoch 102/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1032 - val_loss: 2.0343
# Epoch 103/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0640 - val_loss: 2.0229
# Epoch 104/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0403 - val_loss: 2.0120
# Epoch 105/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0275 - val_loss: 1.9514
# Epoch 106/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9951 - val_loss: 1.9249
# Epoch 107/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9444 - val_loss: 1.9101
# Epoch 108/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9217 - val_loss: 1.8758
# Epoch 109/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9438 - val_loss: 1.8630
# Epoch 110/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9515 - val_loss: 1.8439
# Epoch 111/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9135 - val_loss: 1.8409
# Epoch 112/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8859 - val_loss: 1.8218
# Epoch 113/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8347 - val_loss: 1.7821
# Epoch 114/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8257 - val_loss: 1.7488
# Epoch 115/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8231 - val_loss: 1.7301
# Epoch 116/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7959 - val_loss: 1.7232
# Epoch 117/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7369 - val_loss: 1.7553
# Epoch 118/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7738 - val_loss: 1.7250
# Epoch 119/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7307 - val_loss: 1.6851
# Epoch 120/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7245 - val_loss: 1.6678
# Epoch 121/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7065 - val_loss: 1.6505
# Epoch 122/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7113 - val_loss: 1.6695
# Epoch 123/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7238 - val_loss: 1.6183
# Epoch 124/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6454 - val_loss: 1.5982
# Epoch 125/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6259 - val_loss: 1.5891
# Epoch 126/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6257 - val_loss: 1.5572
# Epoch 127/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5857 - val_loss: 1.5488
# Epoch 128/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6061 - val_loss: 1.5119
# Epoch 129/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5233 - val_loss: 1.4850
# Epoch 130/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5610 - val_loss: 1.4748
# Epoch 131/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5116 - val_loss: 1.4887
# Epoch 132/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4964 - val_loss: 1.4810
# Epoch 133/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4964 - val_loss: 1.4749
# Epoch 134/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5068 - val_loss: 1.4479
# Epoch 135/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4306 - val_loss: 1.4277
# Epoch 136/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4614 - val_loss: 1.4454
# Epoch 137/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4184 - val_loss: 1.4250
# Epoch 138/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4111 - val_loss: 1.4287
# Epoch 139/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4037 - val_loss: 1.3878
# Epoch 140/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3879 - val_loss: 1.3509
# Epoch 141/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3889 - val_loss: 1.3493
# Epoch 142/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3757 - val_loss: 1.3653
# Epoch 143/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3391 - val_loss: 1.3372
# Epoch 144/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3058 - val_loss: 1.2804
# Epoch 145/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3386 - val_loss: 1.2937
# Epoch 146/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3410 - val_loss: 1.2908
# Epoch 147/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3190 - val_loss: 1.2497
# Epoch 148/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3286 - val_loss: 1.2597
# Epoch 149/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2589 - val_loss: 1.2421
# Epoch 150/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2615 - val_loss: 1.2195
# Epoch 151/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2320 - val_loss: 1.2079
# Epoch 152/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2710 - val_loss: 1.2094
# Epoch 153/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2237 - val_loss: 1.1831
# Epoch 154/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2342 - val_loss: 1.1768
# Epoch 155/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2484 - val_loss: 1.1577
# Epoch 156/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2350 - val_loss: 1.1652
# Epoch 157/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1926 - val_loss: 1.1476
# Epoch 158/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2110 - val_loss: 1.1275
# Epoch 159/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1634 - val_loss: 1.1356
# Epoch 160/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1339 - val_loss: 1.1174
# Epoch 161/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1348 - val_loss: 1.1101
# Epoch 162/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1650 - val_loss: 1.1119
# Epoch 163/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0824 - val_loss: 1.0958
# Epoch 164/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1124 - val_loss: 1.0943
# Epoch 165/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0983 - val_loss: 1.0963
# Epoch 166/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0687 - val_loss: 1.0866
# Epoch 167/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1321 - val_loss: 1.0695
# Epoch 168/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0468 - val_loss: 1.0818
# Epoch 169/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0902 - val_loss: 1.0415
# Epoch 170/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0615 - val_loss: 1.0168
# Epoch 171/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0655 - val_loss: 1.0398
# Epoch 172/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0473 - val_loss: 1.0528
# Epoch 173/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0095 - val_loss: 1.0106
# Epoch 174/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0494 - val_loss: 0.9805
# Epoch 175/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9923 - val_loss: 0.9850
# Epoch 176/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9955 - val_loss: 0.9899
# Epoch 177/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0192 - val_loss: 0.9448
# Epoch 178/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9662 - val_loss: 0.9251
# Epoch 179/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9639 - val_loss: 0.9476
# Epoch 180/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9914 - val_loss: 0.9639
# Epoch 181/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9506 - val_loss: 0.9549
# Epoch 182/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9345 - val_loss: 0.9481
# Epoch 183/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9549 - val_loss: 0.9216
# Epoch 184/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9100 - val_loss: 0.9205
# Epoch 185/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9239 - val_loss: 0.9182
# Epoch 186/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9175 - val_loss: 0.8969
# Epoch 187/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8906 - val_loss: 0.8869
# Epoch 188/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9047 - val_loss: 0.8719
# Epoch 189/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8840 - val_loss: 0.8714
# Epoch 190/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8478 - val_loss: 0.8742
# Epoch 191/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9135 - val_loss: 0.8545
# Epoch 192/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8979 - val_loss: 0.8303
# Epoch 193/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8885 - val_loss: 0.8438
# Epoch 194/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8496 - val_loss: 0.8246
# Epoch 195/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8548 - val_loss: 0.8576
# Epoch 196/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7892 - val_loss: 0.8429
# Epoch 197/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8652 - val_loss: 0.8261
# Epoch 198/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8425 - val_loss: 0.8249
# Epoch 199/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8329 - val_loss: 0.8473
# Epoch 200/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8350 - val_loss: 0.8396
# Epoch 201/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7710 - val_loss: 0.8305
# Epoch 202/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7917 - val_loss: 0.8097
# Epoch 203/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7872 - val_loss: 0.7943
# Epoch 204/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7934 - val_loss: 0.7702
# Epoch 205/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8215 - val_loss: 0.7570
# Epoch 206/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7581 - val_loss: 0.7567
# Epoch 207/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7648 - val_loss: 0.7670
# Epoch 208/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7872 - val_loss: 0.7598
# Epoch 209/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7931 - val_loss: 0.7468
# Epoch 210/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7703 - val_loss: 0.7866
# Epoch 211/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7661 - val_loss: 0.7854
# Epoch 212/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7264 - val_loss: 0.7410
# Epoch 213/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7968 - val_loss: 0.7261
# Epoch 214/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7711 - val_loss: 0.7680
# Epoch 215/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7371 - val_loss: 0.7335
# Epoch 216/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7344 - val_loss: 0.7230
# Epoch 217/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7152 - val_loss: 0.7287
# Epoch 218/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7383 - val_loss: 0.7208
# Epoch 219/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7024 - val_loss: 0.7190
# Epoch 220/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7178 - val_loss: 0.7136
# Epoch 221/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7451 - val_loss: 0.7157
# Epoch 222/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6879 - val_loss: 0.6869
# Epoch 223/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6821 - val_loss: 0.6589
# Epoch 224/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6904 - val_loss: 0.6638
# Epoch 225/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6851 - val_loss: 0.6931
# Epoch 226/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6737 - val_loss: 0.6968
# Epoch 227/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6616 - val_loss: 0.6934
# Epoch 228/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6778 - val_loss: 0.6677
# Epoch 229/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6606 - val_loss: 0.6729
# Epoch 230/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6452 - val_loss: 0.6851
# Epoch 231/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6594 - val_loss: 0.6634
# Epoch 232/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6662 - val_loss: 0.6601
# Epoch 233/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6569 - val_loss: 0.6663
# Epoch 234/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6658 - val_loss: 0.6704
# Epoch 235/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6788 - val_loss: 0.6498
# Epoch 236/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6363 - val_loss: 0.6575
# Epoch 237/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6502 - val_loss: 0.6548
# Epoch 238/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6616 - val_loss: 0.6744
# Epoch 239/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6061 - val_loss: 0.6321
# Epoch 240/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6264 - val_loss: 0.6421
# Epoch 241/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6570 - val_loss: 0.6484
# Epoch 242/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6309 - val_loss: 0.6429
# Epoch 243/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6256 - val_loss: 0.6487
# Epoch 244/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6188 - val_loss: 0.6173
# Epoch 245/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6336 - val_loss: 0.6187
# Epoch 246/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6267 - val_loss: 0.6361
# Epoch 247/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6280 - val_loss: 0.5896
# Epoch 248/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5960 - val_loss: 0.6166
# Epoch 249/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5896 - val_loss: 0.6419
# Epoch 250/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6229 - val_loss: 0.6183
# Epoch 251/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5991 - val_loss: 0.6011
# Epoch 252/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5583 - val_loss: 0.5957
# Epoch 253/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6041 - val_loss: 0.5866
# Epoch 254/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5522 - val_loss: 0.6057
# Epoch 255/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5579 - val_loss: 0.6151
# Epoch 256/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5564 - val_loss: 0.5992
# Epoch 257/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6166 - val_loss: 0.5958
# Epoch 258/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5562 - val_loss: 0.6126
# Epoch 259/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5942 - val_loss: 0.5874
# Epoch 260/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5463 - val_loss: 0.5626
# Epoch 261/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5936 - val_loss: 0.5660
# Epoch 262/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5536 - val_loss: 0.5895
# Epoch 263/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5722 - val_loss: 0.5716
# Epoch 264/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5476 - val_loss: 0.5565
# Epoch 265/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5469 - val_loss: 0.5707
# Epoch 266/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5251 - val_loss: 0.5467
# Epoch 267/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5382 - val_loss: 0.5321
# Epoch 268/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5455 - val_loss: 0.5466
# Epoch 269/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5629 - val_loss: 0.5745
# Epoch 270/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5147 - val_loss: 0.5855
# Epoch 271/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5111 - val_loss: 0.5839
# Epoch 272/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5317 - val_loss: 0.5984
# Epoch 273/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5246 - val_loss: 0.5589
# Epoch 274/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5129 - val_loss: 0.5515
# Epoch 275/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5233 - val_loss: 0.5758
# Epoch 276/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5311 - val_loss: 0.5674
# Epoch 277/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4959 - val_loss: 0.5587
# Epoch 278/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5609 - val_loss: 0.5480
# Epoch 279/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5450 - val_loss: 0.5561
# Epoch 280/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5279 - val_loss: 0.5631
# Epoch 281/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5299 - val_loss: 0.5605
# Epoch 282/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5281 - val_loss: 0.4906
# Epoch 283/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5066 - val_loss: 0.4918
# Epoch 284/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5372 - val_loss: 0.5342
# Epoch 285/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5025 - val_loss: 0.5492
# Epoch 286/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5249 - val_loss: 0.5445
# Epoch 287/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5181 - val_loss: 0.5128
# Epoch 288/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4846 - val_loss: 0.4973
# Epoch 289/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5172 - val_loss: 0.5086
# Epoch 290/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4859 - val_loss: 0.4964
# Epoch 291/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4811 - val_loss: 0.4675
# Epoch 292/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4983 - val_loss: 0.4921
# Epoch 293/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4785 - val_loss: 0.5169
# Epoch 294/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5034 - val_loss: 0.5063
# Epoch 295/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5077 - val_loss: 0.4996
# Epoch 296/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4733 - val_loss: 0.5249
# Epoch 297/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4794 - val_loss: 0.5175
# Epoch 298/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4988 - val_loss: 0.5077
# Epoch 299/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4797 - val_loss: 0.5186
# Epoch 300/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4711 - val_loss: 0.5247
# Epoch 301/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4809 - val_loss: 0.5449
# Epoch 302/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4741 - val_loss: 0.5184
# Epoch 303/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5016 - val_loss: 0.5419
# Epoch 304/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4856 - val_loss: 0.5242
# Epoch 305/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4605 - val_loss: 0.5225
# Epoch 306/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4606 - val_loss: 0.5496
# Epoch 307/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4761 - val_loss: 0.5139
# Epoch 308/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4476 - val_loss: 0.4827
# Epoch 309/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4887 - val_loss: 0.4664
# Epoch 310/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4608 - val_loss: 0.4814
# Epoch 311/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4748 - val_loss: 0.5033
# Epoch 312/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4438 - val_loss: 0.4826
# Epoch 313/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4593 - val_loss: 0.5078
# Epoch 314/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4493 - val_loss: 0.4823
# Epoch 315/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4535 - val_loss: 0.4796
# Epoch 316/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4787 - val_loss: 0.5019
# Epoch 317/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4446 - val_loss: 0.5253
# Epoch 318/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4602 - val_loss: 0.5019
# Epoch 319/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4415 - val_loss: 0.4930
# Epoch 320/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4764 - val_loss: 0.5052
# Epoch 321/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4257 - val_loss: 0.4898
# Epoch 322/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4371 - val_loss: 0.4295
# Epoch 323/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4315 - val_loss: 0.4508
# Epoch 324/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4617 - val_loss: 0.4659
# Epoch 325/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4250 - val_loss: 0.4574
# Epoch 326/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4196 - val_loss: 0.4241
# Epoch 327/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4233 - val_loss: 0.5000
# Epoch 328/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4401 - val_loss: 0.5133
# Epoch 329/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4284 - val_loss: 0.4626
# Epoch 330/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4506 - val_loss: 0.4338
# Epoch 331/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4106 - val_loss: 0.4196
# Epoch 332/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4475 - val_loss: 0.4618
# Epoch 333/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4657 - val_loss: 0.4809
# Epoch 334/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4134 - val_loss: 0.4592
# Epoch 335/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4182 - val_loss: 0.4607
# Epoch 336/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4446 - val_loss: 0.4663
# Epoch 337/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4281 - val_loss: 0.4370
# Epoch 338/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4669 - val_loss: 0.4270
# Epoch 339/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4534 - val_loss: 0.4554
# Epoch 340/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4147 - val_loss: 0.4622
# Epoch 341/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4106 - val_loss: 0.4895
# Epoch 342/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4147 - val_loss: 0.4769
# Epoch 343/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4202 - val_loss: 0.4775
# Epoch 344/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4284 - val_loss: 0.4669
# Epoch 345/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4027 - val_loss: 0.4556
# Epoch 346/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4132 - val_loss: 0.4358
# Epoch 347/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4033 - val_loss: 0.4236
# Epoch 348/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4069 - val_loss: 0.4440
# Epoch 349/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4412 - val_loss: 0.4645
# Epoch 350/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4138 - val_loss: 0.4373
# Epoch 351/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4215 - val_loss: 0.4408
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Training R2 Score: 0.8493298977888569
# Testing R2 Score: 0.8631347779258247
# Training Mean Absolute Error: 0.24331099454447966
# Testing Mean Absolute Error: 0.2836926362050229
