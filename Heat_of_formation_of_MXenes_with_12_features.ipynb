# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn import preprocessing
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, r2_score,mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2024-10-06 13:31:16.205577: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dataset = pd.read_csv("data_for_traing_ml_models.csv")

#####################

'''
12-feature dataset is run on Simple Linear Regression, LASSO, Ridge, Random Forest and Neural Network models for the prediction of Heat of Formation of MXenes.
'''
# Out:
# '\n12-feature dataset is run on Simple Linear Regression, LASSO, Ridge, Random Forest and Neural Network models for the prediction of Heat of Formation of MXenes.\n'

# %%
# take a look at the dataset
dataset.head()
dataset.describe()
# Out:
#        Work_function  Heat_of_formation  Energy_above_convex_hull   Length(x)  \
# count     275.000000         275.000000                275.000000  275.000000
# mean        4.264700          -1.062837                  0.315639  311.577091
# std         1.530484           0.835387                  0.228956   20.841980
# min         1.347678          -2.984132                  0.000000  262.100000
# 25%         2.792242          -1.646810                  0.162571  294.700000
# 50%         4.537063          -1.079087                  0.268825  312.500000
# 75%         5.349280          -0.483631                  0.424251  324.000000
# max         7.271891           0.957153                  1.138551  378.300000
#
#        Radius_of_orbital_of_metal  Radius_of_orbital_of_support  \
# count                  275.000000                    275.000000
# mean                    65.518545                     54.219636
# std                     16.428133                      5.409809
# min                     38.900000                     48.800000
# 25%                     48.900000                     48.800000
# 50%                     74.600000                     59.600000
# 75%                     79.000000                     59.600000
# max                     86.500000                     59.600000
#
#        Radius_of_orbital_of_termination  Ionisation_potential_of_metal  \
# count                        275.000000                     275.000000
# mean                          45.983636                       6.980777
# std                           13.987596                       0.518915
# min                           36.000000                       6.217000
# 25%                           38.900000                       6.633900
# 50%                           41.400000                       6.825000
# 75%                           41.400000                       7.264100
# max                           86.500000                       7.980000
#
#        Ionisation_potential_of_support  Ionisation_potential_of_termination  \
# count                       275.000000                           275.000000
# mean                         12.891248                            12.719608
# std                           1.639873                             3.765861
# min                          11.260300                             6.217000
# 25%                          11.260300                             7.980000
# 50%                          11.260300                            13.017000
# 75%                          14.534100                            13.618000
# max                          14.534100                            17.422800
#
#        Electronegativity_of_metal  Electronegativity_of_support  \
# count                  275.000000                    275.000000
# mean                     1.601527                      2.794109
# std                      0.333816                      0.245445
# min                      1.220000                      2.550000
# 25%                      1.330000                      2.550000
# 50%                      1.540000                      2.550000
# 75%                      1.630000                      3.040000
# max                      2.360000                      3.040000
#
#        Electronegativity_of_termination  Electron_affinity_of_metal  \
# count                        275.000000                  275.000000
# mean                           2.951018                    0.394964
# std                            0.903641                    0.364981
# min                            1.220000                   -0.500000
# 25%                            2.360000                    0.189000
# 50%                            2.820000                    0.323000
# 75%                            3.440000                    0.749000
# max                            3.980000                    0.894000
#
#        Electron_affinity_of_support  Electron_affinity_of_termination
# count                    275.000000                        275.000000
# mean                       0.598422                          1.755294
# std                        0.667210                          1.099077
# min                       -0.070000                         -0.500000
# 25%                       -0.070000                          0.894000
# 50%                        1.262000                          1.439000
# 75%                        1.262000                          1.827000
# max                        1.262000                          3.401000

# %%
cdf = dataset[['Work_function','Heat_of_formation','Energy_above_convex_hull','Length(x)','Radius_of_orbital_of_metal','Radius_of_orbital_of_support','Radius_of_orbital_of_termination','Ionisation_potential_of_metal','Ionisation_potential_of_support','Ionisation_potential_of_termination','Electronegativity_of_metal','Electronegativity_of_support','Electronegativity_of_termination','Electron_affinity_of_metal','Electron_affinity_of_support','Electron_affinity_of_termination']]
cdf.head(9)
# Out:
#    Work_function  Heat_of_formation  Energy_above_convex_hull  Length(x)  \
# 0       2.271378          -1.345952                  0.242880      330.4
# 1       1.588009          -1.199954                  0.452744      335.0
# 2       2.209840          -0.317344                  0.473693      290.6
# 3       2.463148          -0.594739                  0.327053      285.0
# 4       2.329750          -1.597694                  0.163033      298.9
# 5       2.429486          -1.645322                  0.315790      320.4
# 6       6.244289          -0.755420                  0.290092      293.1
# 7       4.424606          -1.265524                  0.269073      316.7
# 8       4.468438          -1.715968                  0.168985      348.9
#
#    Radius_of_orbital_of_metal  Radius_of_orbital_of_support  \
# 0                        82.9                          59.6
# 1                        53.9                          59.6
# 2                        74.6                          59.6
# 3                        70.2                          48.8
# 4                        48.9                          48.8
# 5                        79.0                          48.8
# 6                        38.9                          59.6
# 7                        78.4                          59.6
# 8                        86.5                          59.6
#
#    Radius_of_orbital_of_termination  Ionisation_potential_of_metal  \
# 0                              41.4                         6.8250
# 1                              41.4                         6.5614
# 2                              41.4                         7.9800
# 3                              41.4                         7.0942
# 4                              41.4                         6.8282
# 5                              41.4                         6.6339
# 6                              36.0                         7.4340
# 7                              36.0                         7.8900
# 8                              36.0                         6.2170
#
#    Ionisation_potential_of_support  Ionisation_potential_of_termination  \
# 0                          11.2603                              13.0170
# 1                          11.2603                              13.0170
# 2                          11.2603                              13.0170
# 3                          14.5341                              13.0170
# 4                          14.5341                              13.0170
# 5                          14.5341                              13.0170
# 6                          11.2603                              17.4228
# 7                          11.2603                              17.4228
# 8                          11.2603                              17.4228
#
#    Electronegativity_of_metal  Electronegativity_of_support  \
# 0                        1.30                          2.55
# 1                        1.36                          2.55
# 2                        2.36                          2.55
# 3                        2.16                          3.04
# 4                        1.54                          3.04
# 5                        1.33                          3.04
# 6                        1.55                          2.55
# 7                        1.50                          2.55
# 8                        1.22                          2.55
#
#    Electronegativity_of_termination  Electron_affinity_of_metal  \
# 0                              2.82                       0.178
# 1                              2.82                       0.189
# 2                              2.82                       0.816
# 3                              2.82                       0.749
# 4                              2.82                       0.087
# 5                              2.82                       0.427
# 6                              3.98                      -0.500
# 7                              3.98                       0.323
# 8                              3.98                       0.308
#
#    Electron_affinity_of_support  Electron_affinity_of_termination
# 0                         1.262                             1.827
# 1                         1.262                             1.827
# 2                         1.262                             1.827
# 3                        -0.070                             1.827
# 4                        -0.070                             1.827
# 5                        -0.070                             1.827
# 6                         1.262                             3.401
# 7                         1.262                             3.401
# 8                         1.262                             3.401

# %%
###################### Simple Linear Regression

regr = LinearRegression()

# Assuming 'HoF', 'E_Hull', 'Length(x)', ..., are your features
features = ['Radius_of_orbital_of_metal','Radius_of_orbital_of_support','Radius_of_orbital_of_termination', 'Ionisation_potential_of_metal','Ionisation_potential_of_support','Ionisation_potential_of_termination', 'Electronegativity_of_metal','Electronegativity_of_support','Electronegativity_of_termination','Electron_affinity_of_metal','Electron_affinity_of_support','Electron_affinity_of_termination']
target = ['Heat_of_formation']

# Split the data into train and test sets
train, test = train_test_split(dataset, test_size=0.2, random_state=42)

# Train set
train_x = np.asanyarray(train[features])
train_y = np.asanyarray(train[target])

# Test set
test_x = np.asanyarray(test[features])
test_y = np.asanyarray(test[target])

# Create and train the Linear Regression model
regr.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat = regr.predict(train_x)
test_y_hat = regr.predict(test_x)

# Calculate MSE, MAE, and R2 for the train set
train_mse = mean_squared_error(train_y, train_y_hat)
train_mae = mean_absolute_error(train_y, train_y_hat)
train_r2 = r2_score(train_y, train_y_hat)

# Calculate MSE, MAE, and R2 for the test set
test_mse = mean_squared_error(test_y, test_y_hat)
test_mae = mean_absolute_error(test_y, test_y_hat)
test_r2 = r2_score(test_y, test_y_hat)

# Print the results
print('Linear Regression\n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse)
print("MAE: %.2f" % train_mae)
print("R2 Score: %.2f" % train_r2)
print('LinearRegression\n')
print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse)
print("MAE: %.2f" % test_mae)
print("R2 Score: %.2f" % test_r2)
# Out:
# Linear Regression
#
# Train set metrics:
# MAE: 0.29
# R2 Score: 0.80
# LinearRegression
#
#
# Test set metrics:
# MAE: 0.29
# R2 Score: 0.85

# %%
####################### LASSO Regression


# Initialize LASSO model
regr1 = Lasso()
# Create and train the LASSO Regression model
regr1.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat1 = regr1.predict(train_x)
test_y_hat1 = regr1.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse1 = mean_squared_error(train_y, train_y_hat1)
train_mae1 = mean_absolute_error(train_y, train_y_hat1)
train_r2_1 = r2_score(train_y, train_y_hat1)

# Calculate MSE, MAE, and R2 for the test set
test_mse1 = mean_squared_error(test_y, test_y_hat1)
test_mae1 = mean_absolute_error(test_y, test_y_hat1)
test_r2_1 = r2_score(test_y, test_y_hat1)

# Print the results
print('LASSO Regression')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse1)
print("MAE: %.2f" % train_mae1)
print("R2 Score: %.2f" % train_r2_1)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse1)
print("MAE: %.2f" % test_mae1)
print("R2 Score: %.2f" % test_r2_1)
# Out:
# LASSO Regression
# Train set metrics:
# MAE: 0.54
# R2 Score: 0.31
#
# Test set metrics:
# MAE: 0.58
# R2 Score: 0.37

# %%
####################### Ridge Regression



# Initialize Ridge Regression
regr2 = Ridge()
# Create and train the Ridge Regression model
regr2.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat2 = regr2.predict(train_x)
test_y_hat2 = regr2.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse2 = mean_squared_error(train_y, train_y_hat2)
train_mae2 = mean_absolute_error(train_y, train_y_hat2)
train_r2_2 = r2_score(train_y, train_y_hat2)

# Calculate MSE, MAE, and R2 for the test set
test_mse2 = mean_squared_error(test_y, test_y_hat2)
test_mae2 = mean_absolute_error(test_y, test_y_hat2)
test_r2_2 = r2_score(test_y, test_y_hat2)

# Print the results
print('Ridge Regression\n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse2)
print("MAE: %.2f" % train_mae2)
print("R2 Score: %.2f" % train_r2_2)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse2)
print("MAE: %.2f" % test_mae2)
print("R2 Score: %.2f" % test_r2_2)
# Out:
# Ridge Regression
#
# Train set metrics:
# MAE: 0.29
# R2 Score: 0.80
#
# Test set metrics:
# MAE: 0.29
# R2 Score: 0.85

# %%
###################### Random Forest Regression



# Initialize Random Forest Regression
regr3 = RandomForestRegressor()
# Create and train the Random Forest Regression model
regr3.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat3 = regr3.predict(train_x)
test_y_hat3 = regr3.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse3 = mean_squared_error(train_y, train_y_hat3)
train_mae3 = mean_absolute_error(train_y, train_y_hat3)
train_r2_3 = r2_score(train_y, train_y_hat3)

# Calculate MSE, MAE, and R2 for the test set
test_mse3 = mean_squared_error(test_y, test_y_hat3)
test_mae3 = mean_absolute_error(test_y, test_y_hat3)
test_r2_3 = r2_score(test_y, test_y_hat3)

# Print the results
print('Random Forest Regression \n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse3)
print("MAE: %.2f" % train_mae3)
print("R2 Score: %.2f" % train_r2_3)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse3)
print("MAE: %.2f" % test_mae3)
print("R2 Score: %.2f" % test_r2_3)
# Out:
# /home/azaan/anaconda3/envs/data_science/lib/python3.9/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest Regression
#
# Train set metrics:
# MAE: 0.15
# R2 Score: 0.94
#
# Test set metrics:
# MAE: 0.23
# R2 Score: 0.90

# %% [markdown]
# ################## Neural Network Regression

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization

# Assuming 'dataset' is already loaded
dataset_columns = dataset.columns
columns_to_exclude = ['Formula', 'M', 'X', 'T', 'Work_function', 'Heat_of_formation', 'Energy_above_convex_hull', 'Length(x)']

# Preprocess the data
predictors = dataset.drop(columns=columns_to_exclude)
target = dataset['Heat_of_formation']
predictors_norm = (predictors - predictors.mean()) / predictors.std()

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.2, random_state=42)

# Get the number of input features
n_cols = predictors_norm.shape[1]

def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(512, activation='relu', input_shape=(n_cols,), kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(256, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu', kernel_regularizer='l2'))
    model.add(Dense(1))
    optimizer = Adamax(learning_rate=0.002)
   
    model.compile(optimizer=optimizer, loss='mae')
    return model


# Build the model
model = regression_model()

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model
model.fit(X_train, y_train, batch_size=32, validation_split=0.2, epochs=600, verbose=1, callbacks=[early_stopping])

# Make predictions on the training set
train_predictions = model.predict(X_train)

# Make predictions on the testing set
test_predictions = model.predict(X_test)

# Calculate R2 score for training and testing sets
r2_train = r2_score(y_train, train_predictions)
r2_test = r2_score(y_test, test_predictions)

# Calculate MAE for training and testing sets
mae_train = mean_absolute_error(y_train, train_predictions)
mae_test = mean_absolute_error(y_test, test_predictions)

# Print the results
print(f'Training R2 Score: {r2_train}')
print(f'Testing R2 Score: {r2_test}')
print(f'Training Mean Absolute Error: {mae_train}')
print(f'Testing Mean Absolute Error: {mae_test}')
# Out:
# /home/azaan/anaconda3/envs/data_science/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-10-06 13:31:19.057045: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:31:19.066534: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:31:19.066773: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:31:19.068234: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:31:19.068545: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:31:19.068737: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:31:19.123444: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:31:19.123678: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:31:19.123852: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:31:19.123980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3509 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 960M, pci bus id: 0000:01:00.0, compute capability: 5.0
# Epoch 1/600
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728203482.361913  242622 service.cc:145] XLA service 0x77e7ac007020 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728203482.361966  242622 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 960M, Compute Capability 5.0
# 2024-10-06 13:31:22.489020: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-06 13:31:22.843948: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 51s 10s/step - loss: 8.0268
# I0000 00:00:1728203489.707731  242622 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - loss: 7.7202 - val_loss: 7.1871
# Epoch 2/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9967 - val_loss: 7.0092
# Epoch 3/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7786 - val_loss: 6.9123
# Epoch 4/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6004 - val_loss: 6.8061
# Epoch 5/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5225 - val_loss: 6.6970
# Epoch 6/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3825 - val_loss: 6.5901
# Epoch 7/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3205 - val_loss: 6.4795
# Epoch 8/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1560 - val_loss: 6.3790
# Epoch 9/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0764 - val_loss: 6.2629
# Epoch 10/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0415 - val_loss: 6.1560
# Epoch 11/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9324 - val_loss: 6.0625
# Epoch 12/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8759 - val_loss: 5.9907
# Epoch 13/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7812 - val_loss: 5.9080
# Epoch 14/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6958 - val_loss: 5.8377
# Epoch 15/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6475 - val_loss: 5.7590
# Epoch 16/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6448 - val_loss: 5.6778
# Epoch 17/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5125 - val_loss: 5.5934
# Epoch 18/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4257 - val_loss: 5.5223
# Epoch 19/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4242 - val_loss: 5.4473
# Epoch 20/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3284 - val_loss: 5.3771
# Epoch 21/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2064 - val_loss: 5.2941
# Epoch 22/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.1836 - val_loss: 5.2352
# Epoch 23/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.1489 - val_loss: 5.1895
# Epoch 24/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0554 - val_loss: 5.1256
# Epoch 25/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0122 - val_loss: 5.0535
# Epoch 26/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9484 - val_loss: 4.9757
# Epoch 27/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8796 - val_loss: 4.8962
# Epoch 28/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9477 - val_loss: 4.8522
# Epoch 29/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7720 - val_loss: 4.8177
# Epoch 30/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7559 - val_loss: 4.7672
# Epoch 31/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6766 - val_loss: 4.7092
# Epoch 32/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6480 - val_loss: 4.6546
# Epoch 33/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5627 - val_loss: 4.5993
# Epoch 34/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5455 - val_loss: 4.5445
# Epoch 35/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4462 - val_loss: 4.4678
# Epoch 36/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.4246 - val_loss: 4.4118
# Epoch 37/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3689 - val_loss: 4.3731
# Epoch 38/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3005 - val_loss: 4.3545
# Epoch 39/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2810 - val_loss: 4.2854
# Epoch 40/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1989 - val_loss: 4.2181
# Epoch 41/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2147 - val_loss: 4.1683
# Epoch 42/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1347 - val_loss: 4.1209
# Epoch 43/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1114 - val_loss: 4.0760
# Epoch 44/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0650 - val_loss: 4.0212
# Epoch 45/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0049 - val_loss: 3.9496
# Epoch 46/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9644 - val_loss: 3.8983
# Epoch 47/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9294 - val_loss: 3.8594
# Epoch 48/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8621 - val_loss: 3.8323
# Epoch 49/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8227 - val_loss: 3.8008
# Epoch 50/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7820 - val_loss: 3.7344
# Epoch 51/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7544 - val_loss: 3.6716
# Epoch 52/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6881 - val_loss: 3.6354
# Epoch 53/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6805 - val_loss: 3.6062
# Epoch 54/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6457 - val_loss: 3.5593
# Epoch 55/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5795 - val_loss: 3.5151
# Epoch 56/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5628 - val_loss: 3.4916
# Epoch 57/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5177 - val_loss: 3.4541
# Epoch 58/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4602 - val_loss: 3.4129
# Epoch 59/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4108 - val_loss: 3.3809
# Epoch 60/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3822 - val_loss: 3.3336
# Epoch 61/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3488 - val_loss: 3.2830
# Epoch 62/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2931 - val_loss: 3.2405
# Epoch 63/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2543 - val_loss: 3.2074
# Epoch 64/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2844 - val_loss: 3.1724
# Epoch 65/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2003 - val_loss: 3.1529
# Epoch 66/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.1651 - val_loss: 3.1308
# Epoch 67/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.1288 - val_loss: 3.0982
# Epoch 68/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0817 - val_loss: 3.0452
# Epoch 69/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0758 - val_loss: 2.9985
# Epoch 70/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.0641 - val_loss: 2.9696
# Epoch 71/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9629 - val_loss: 2.9415
# Epoch 72/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9396 - val_loss: 2.9029
# Epoch 73/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9486 - val_loss: 2.8804
# Epoch 74/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8950 - val_loss: 2.8585
# Epoch 75/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8629 - val_loss: 2.8225
# Epoch 76/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8199 - val_loss: 2.7776
# Epoch 77/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7747 - val_loss: 2.7191
# Epoch 78/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7711 - val_loss: 2.6880
# Epoch 79/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7155 - val_loss: 2.6675
# Epoch 80/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7280 - val_loss: 2.6523
# Epoch 81/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6661 - val_loss: 2.6119
# Epoch 82/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6503 - val_loss: 2.5538
# Epoch 83/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6076 - val_loss: 2.5175
# Epoch 84/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5729 - val_loss: 2.4787
# Epoch 85/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5780 - val_loss: 2.4633
# Epoch 86/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5380 - val_loss: 2.4468
# Epoch 87/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4783 - val_loss: 2.4144
# Epoch 88/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4761 - val_loss: 2.4132
# Epoch 89/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4395 - val_loss: 2.3768
# Epoch 90/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4506 - val_loss: 2.3878
# Epoch 91/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3943 - val_loss: 2.3734
# Epoch 92/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3826 - val_loss: 2.2996
# Epoch 93/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3474 - val_loss: 2.2787
# Epoch 94/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3175 - val_loss: 2.2575
# Epoch 95/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2940 - val_loss: 2.2409
# Epoch 96/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2821 - val_loss: 2.2244
# Epoch 97/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2614 - val_loss: 2.2001
# Epoch 98/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2109 - val_loss: 2.1960
# Epoch 99/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1588 - val_loss: 2.1721
# Epoch 100/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1178 - val_loss: 2.1520
# Epoch 101/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1135 - val_loss: 2.1411
# Epoch 102/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0897 - val_loss: 2.1479
# Epoch 103/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0782 - val_loss: 2.0723
# Epoch 104/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0839 - val_loss: 2.0105
# Epoch 105/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0324 - val_loss: 1.9884
# Epoch 106/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9994 - val_loss: 1.9833
# Epoch 107/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9690 - val_loss: 1.9568
# Epoch 108/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9467 - val_loss: 1.9344
# Epoch 109/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9269 - val_loss: 1.9325
# Epoch 110/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9342 - val_loss: 1.9005
# Epoch 111/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8995 - val_loss: 1.8707
# Epoch 112/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8676 - val_loss: 1.8430
# Epoch 113/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8211 - val_loss: 1.8424
# Epoch 114/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8343 - val_loss: 1.8127
# Epoch 115/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8263 - val_loss: 1.7865
# Epoch 116/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7636 - val_loss: 1.7813
# Epoch 117/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7659 - val_loss: 1.7522
# Epoch 118/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7587 - val_loss: 1.7261
# Epoch 119/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7724 - val_loss: 1.7085
# Epoch 120/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6994 - val_loss: 1.6990
# Epoch 121/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6876 - val_loss: 1.7034
# Epoch 122/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6670 - val_loss: 1.6634
# Epoch 123/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6490 - val_loss: 1.6192
# Epoch 124/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6793 - val_loss: 1.6144
# Epoch 125/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6479 - val_loss: 1.6253
# Epoch 126/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6420 - val_loss: 1.6103
# Epoch 127/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5688 - val_loss: 1.5954
# Epoch 128/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5624 - val_loss: 1.5614
# Epoch 129/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5728 - val_loss: 1.5513
# Epoch 130/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5393 - val_loss: 1.5373
# Epoch 131/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5025 - val_loss: 1.5400
# Epoch 132/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5282 - val_loss: 1.5012
# Epoch 133/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4781 - val_loss: 1.4511
# Epoch 134/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4549 - val_loss: 1.4207
# Epoch 135/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4170 - val_loss: 1.4219
# Epoch 136/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4395 - val_loss: 1.4344
# Epoch 137/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4401 - val_loss: 1.4163
# Epoch 138/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4041 - val_loss: 1.3810
# Epoch 139/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3955 - val_loss: 1.3829
# Epoch 140/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3650 - val_loss: 1.3817
# Epoch 141/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3479 - val_loss: 1.3651
# Epoch 142/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3337 - val_loss: 1.3370
# Epoch 143/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3075 - val_loss: 1.3276
# Epoch 144/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3342 - val_loss: 1.2947
# Epoch 145/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2925 - val_loss: 1.2983
# Epoch 146/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2740 - val_loss: 1.2865
# Epoch 147/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3005 - val_loss: 1.2774
# Epoch 148/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2443 - val_loss: 1.2581
# Epoch 149/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2572 - val_loss: 1.2329
# Epoch 150/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2537 - val_loss: 1.2362
# Epoch 151/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2085 - val_loss: 1.2041
# Epoch 152/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1942 - val_loss: 1.1875
# Epoch 153/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1962 - val_loss: 1.1946
# Epoch 154/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1832 - val_loss: 1.1943
# Epoch 155/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1937 - val_loss: 1.1812
# Epoch 156/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1094 - val_loss: 1.1613
# Epoch 157/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1374 - val_loss: 1.1323
# Epoch 158/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1578 - val_loss: 1.1406
# Epoch 159/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1084 - val_loss: 1.1342
# Epoch 160/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0768 - val_loss: 1.1226
# Epoch 161/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0996 - val_loss: 1.1263
# Epoch 162/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0758 - val_loss: 1.0726
# Epoch 163/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0587 - val_loss: 1.0740
# Epoch 164/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0879 - val_loss: 1.0900
# Epoch 165/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0359 - val_loss: 1.0846
# Epoch 166/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0276 - val_loss: 1.0605
# Epoch 167/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0473 - val_loss: 1.0133
# Epoch 168/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0181 - val_loss: 0.9844
# Epoch 169/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0175 - val_loss: 0.9915
# Epoch 170/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0102 - val_loss: 0.9896
# Epoch 171/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9989 - val_loss: 0.9741
# Epoch 172/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9856 - val_loss: 0.9743
# Epoch 173/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9603 - val_loss: 0.9709
# Epoch 174/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9947 - val_loss: 0.9509
# Epoch 175/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9304 - val_loss: 0.9486
# Epoch 176/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9488 - val_loss: 0.9517
# Epoch 177/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9336 - val_loss: 0.9477
# Epoch 178/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9416 - val_loss: 0.9385
# Epoch 179/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9085 - val_loss: 0.8946
# Epoch 180/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9122 - val_loss: 0.8750
# Epoch 181/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9123 - val_loss: 0.8988
# Epoch 182/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8617 - val_loss: 0.8765
# Epoch 183/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8682 - val_loss: 0.8809
# Epoch 184/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8898 - val_loss: 0.8822
# Epoch 185/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8507 - val_loss: 0.8589
# Epoch 186/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8318 - val_loss: 0.8343
# Epoch 187/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8610 - val_loss: 0.8328
# Epoch 188/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8568 - val_loss: 0.8344
# Epoch 189/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7990 - val_loss: 0.8401
# Epoch 190/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8340 - val_loss: 0.8347
# Epoch 191/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8055 - val_loss: 0.8052
# Epoch 192/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7712 - val_loss: 0.8098
# Epoch 193/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8173 - val_loss: 0.8150
# Epoch 194/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7873 - val_loss: 0.8152
# Epoch 195/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8092 - val_loss: 0.8128
# Epoch 196/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7977 - val_loss: 0.8177
# Epoch 197/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7657 - val_loss: 0.8063
# Epoch 198/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7671 - val_loss: 0.8170
# Epoch 199/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7665 - val_loss: 0.7761
# Epoch 200/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7356 - val_loss: 0.7582
# Epoch 201/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7411 - val_loss: 0.7616
# Epoch 202/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7300 - val_loss: 0.7530
# Epoch 203/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7223 - val_loss: 0.7581
# Epoch 204/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7313 - val_loss: 0.7342
# Epoch 205/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7060 - val_loss: 0.7458
# Epoch 206/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7381 - val_loss: 0.7328
# Epoch 207/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7353 - val_loss: 0.7164
# Epoch 208/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6888 - val_loss: 0.7008
# Epoch 209/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6803 - val_loss: 0.7207
# Epoch 210/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6805 - val_loss: 0.7121
# Epoch 211/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6700 - val_loss: 0.6851
# Epoch 212/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6747 - val_loss: 0.6851
# Epoch 213/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6877 - val_loss: 0.6900
# Epoch 214/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6965 - val_loss: 0.6905
# Epoch 215/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6868 - val_loss: 0.7050
# Epoch 216/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6911 - val_loss: 0.7300
# Epoch 217/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6910 - val_loss: 0.6601
# Epoch 218/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6776 - val_loss: 0.6796
# Epoch 219/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6751 - val_loss: 0.6418
# Epoch 220/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6229 - val_loss: 0.6422
# Epoch 221/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6336 - val_loss: 0.6267
# Epoch 222/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6166 - val_loss: 0.6245
# Epoch 223/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6169 - val_loss: 0.6212
# Epoch 224/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6132 - val_loss: 0.6019
# Epoch 225/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6084 - val_loss: 0.6352
# Epoch 226/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6183 - val_loss: 0.6394
# Epoch 227/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5756 - val_loss: 0.6312
# Epoch 228/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5765 - val_loss: 0.5901
# Epoch 229/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5878 - val_loss: 0.5913
# Epoch 230/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5704 - val_loss: 0.6039
# Epoch 231/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5795 - val_loss: 0.6310
# Epoch 232/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5475 - val_loss: 0.6123
# Epoch 233/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5669 - val_loss: 0.5832
# Epoch 234/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5613 - val_loss: 0.5857
# Epoch 235/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5491 - val_loss: 0.5653
# Epoch 236/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5581 - val_loss: 0.5445
# Epoch 237/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5539 - val_loss: 0.5665
# Epoch 238/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5449 - val_loss: 0.5736
# Epoch 239/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5350 - val_loss: 0.5603
# Epoch 240/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5425 - val_loss: 0.5606
# Epoch 241/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5407 - val_loss: 0.5349
# Epoch 242/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5209 - val_loss: 0.5694
# Epoch 243/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5563 - val_loss: 0.5681
# Epoch 244/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5242 - val_loss: 0.5548
# Epoch 245/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5274 - val_loss: 0.5581
# Epoch 246/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5283 - val_loss: 0.5550
# Epoch 247/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5292 - val_loss: 0.5485
# Epoch 248/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5554 - val_loss: 0.5586
# Epoch 249/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5032 - val_loss: 0.5742
# Epoch 250/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5409 - val_loss: 0.5513
# Epoch 251/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5195 - val_loss: 0.5273
# Epoch 252/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5271 - val_loss: 0.5355
# Epoch 253/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5007 - val_loss: 0.5553
# Epoch 254/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5204 - val_loss: 0.5213
# Epoch 255/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4921 - val_loss: 0.4951
# Epoch 256/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5161 - val_loss: 0.4919
# Epoch 257/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4890 - val_loss: 0.5290
# Epoch 258/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5040 - val_loss: 0.5188
# Epoch 259/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4714 - val_loss: 0.5264
# Epoch 260/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4755 - val_loss: 0.5307
# Epoch 261/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4828 - val_loss: 0.5561
# Epoch 262/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4898 - val_loss: 0.4972
# Epoch 263/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4781 - val_loss: 0.5336
# Epoch 264/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4791 - val_loss: 0.5192
# Epoch 265/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4665 - val_loss: 0.5074
# Epoch 266/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4711 - val_loss: 0.4984
# Epoch 267/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4914 - val_loss: 0.4974
# Epoch 268/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4744 - val_loss: 0.5188
# Epoch 269/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4558 - val_loss: 0.5030
# Epoch 270/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4567 - val_loss: 0.5012
# Epoch 271/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4259 - val_loss: 0.4754
# Epoch 272/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4612 - val_loss: 0.4546
# Epoch 273/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4361 - val_loss: 0.4791
# Epoch 274/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4442 - val_loss: 0.4878
# Epoch 275/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4242 - val_loss: 0.4927
# Epoch 276/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4560 - val_loss: 0.4956
# Epoch 277/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4331 - val_loss: 0.4842
# Epoch 278/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4174 - val_loss: 0.4712
# Epoch 279/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4519 - val_loss: 0.4829
# Epoch 280/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4276 - val_loss: 0.4523
# Epoch 281/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4461 - val_loss: 0.4360
# Epoch 282/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4292 - val_loss: 0.4595
# Epoch 283/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4029 - val_loss: 0.4906
# Epoch 284/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4077 - val_loss: 0.4881
# Epoch 285/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4286 - val_loss: 0.4745
# Epoch 286/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4345 - val_loss: 0.4785
# Epoch 287/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4466 - val_loss: 0.4779
# Epoch 288/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4181 - val_loss: 0.4446
# Epoch 289/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4048 - val_loss: 0.4348
# Epoch 290/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4205 - val_loss: 0.4500
# Epoch 291/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4107 - val_loss: 0.4539
# Epoch 292/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4203 - val_loss: 0.4529
# Epoch 293/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4126 - val_loss: 0.4518
# Epoch 294/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4000 - val_loss: 0.4451
# Epoch 295/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4156 - val_loss: 0.4428
# Epoch 296/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4020 - val_loss: 0.4470
# Epoch 297/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3884 - val_loss: 0.4438
# Epoch 298/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3805 - val_loss: 0.4345
# Epoch 299/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4156 - val_loss: 0.4289
# Epoch 300/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4176 - val_loss: 0.4130
# Epoch 301/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4050 - val_loss: 0.4186
# Epoch 302/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4034 - val_loss: 0.4373
# Epoch 303/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3662 - val_loss: 0.4328
# Epoch 304/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3574 - val_loss: 0.4906
# Epoch 305/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3947 - val_loss: 0.4616
# Epoch 306/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3633 - val_loss: 0.4127
# Epoch 307/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3879 - val_loss: 0.4346
# Epoch 308/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4050 - val_loss: 0.4484
# Epoch 309/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3875 - val_loss: 0.4284
# Epoch 310/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3840 - val_loss: 0.4201
# Epoch 311/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3696 - val_loss: 0.4104
# Epoch 312/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3807 - val_loss: 0.4305
# Epoch 313/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3835 - val_loss: 0.4489
# Epoch 314/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3642 - val_loss: 0.4461
# Epoch 315/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3863 - val_loss: 0.4116
# Epoch 316/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3677 - val_loss: 0.3993
# Epoch 317/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3635 - val_loss: 0.3925
# Epoch 318/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3608 - val_loss: 0.4032
# Epoch 319/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3375 - val_loss: 0.4352
# Epoch 320/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3535 - val_loss: 0.4498
# Epoch 321/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3820 - val_loss: 0.4226
# Epoch 322/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3688 - val_loss: 0.4349
# Epoch 323/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3867 - val_loss: 0.4203
# Epoch 324/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3756 - val_loss: 0.4159
# Epoch 325/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3778 - val_loss: 0.4317
# Epoch 326/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3862 - val_loss: 0.4005
# Epoch 327/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3610 - val_loss: 0.3901
# Epoch 328/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3526 - val_loss: 0.3994
# Epoch 329/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3479 - val_loss: 0.4077
# Epoch 330/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3674 - val_loss: 0.4253
# Epoch 331/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3469 - val_loss: 0.3932
# Epoch 332/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3460 - val_loss: 0.4016
# Epoch 333/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3319 - val_loss: 0.4201
# Epoch 334/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3372 - val_loss: 0.3975
# Epoch 335/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3583 - val_loss: 0.4118
# Epoch 336/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3745 - val_loss: 0.4194
# Epoch 337/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3665 - val_loss: 0.4238
# Epoch 338/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3518 - val_loss: 0.4038
# Epoch 339/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3332 - val_loss: 0.3905
# Epoch 340/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3571 - val_loss: 0.3756
# Epoch 341/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3308 - val_loss: 0.3742
# Epoch 342/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3305 - val_loss: 0.3914
# Epoch 343/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3543 - val_loss: 0.3932
# Epoch 344/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3426 - val_loss: 0.3883
# Epoch 345/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3453 - val_loss: 0.3705
# Epoch 346/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3348 - val_loss: 0.3771
# Epoch 347/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3405 - val_loss: 0.3735
# Epoch 348/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3206 - val_loss: 0.3706
# Epoch 349/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3328 - val_loss: 0.3864
# Epoch 350/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3192 - val_loss: 0.3968
# Epoch 351/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3490 - val_loss: 0.3918
# Epoch 352/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3272 - val_loss: 0.3896
# Epoch 353/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3158 - val_loss: 0.3879
# Epoch 354/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3131 - val_loss: 0.3788
# Epoch 355/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3875 - val_loss: 0.3870
# Epoch 356/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3410 - val_loss: 0.4021
# Epoch 357/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3396 - val_loss: 0.3950
# Epoch 358/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3199 - val_loss: 0.3963
# Epoch 359/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3374 - val_loss: 0.3923
# Epoch 360/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3425 - val_loss: 0.3757
# Epoch 361/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3354 - val_loss: 0.3359
# Epoch 362/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3270 - val_loss: 0.3456
# Epoch 363/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3067 - val_loss: 0.3793
# Epoch 364/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3319 - val_loss: 0.3745
# Epoch 365/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3494 - val_loss: 0.3682
# Epoch 366/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3295 - val_loss: 0.3884
# Epoch 367/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3019 - val_loss: 0.3929
# Epoch 368/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3120 - val_loss: 0.3714
# Epoch 369/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3266 - val_loss: 0.3452
# Epoch 370/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3496 - val_loss: 0.3657
# Epoch 371/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3175 - val_loss: 0.3830
# Epoch 372/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3250 - val_loss: 0.3686
# Epoch 373/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3226 - val_loss: 0.3638
# Epoch 374/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3015 - val_loss: 0.3641
# Epoch 375/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3043 - val_loss: 0.3750
# Epoch 376/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3167 - val_loss: 0.3726
# Epoch 377/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3358 - val_loss: 0.3416
# Epoch 378/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3226 - val_loss: 0.3439
# Epoch 379/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3044 - val_loss: 0.3665
# Epoch 380/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3062 - val_loss: 0.3655
# Epoch 381/600
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2994 - val_loss: 0.3543
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# Training R2 Score: 0.9228993219825716
# Testing R2 Score: 0.9030047501836342
# Training Mean Absolute Error: 0.1762444123134672
# Testing Mean Absolute Error: 0.23452395183920507
