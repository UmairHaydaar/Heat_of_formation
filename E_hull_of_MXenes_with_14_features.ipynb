# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn import preprocessing
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, r2_score,mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2024-10-06 13:38:06.085900: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dataset = pd.read_csv("data_for_traing_ml_models.csv")

#####################

'''
14-feature dataset is run on Simple Linear Regression, LASSO, Ridge, Random Forest and Neural Network models for the prediction of energy above convex hull of MXenes.
'''
# Out:
# '\n14-feature dataset is run on Simple Linear Regression, LASSO, Ridge, Random Forest and Neural Network models for the prediction of energy above convex hull of MXenes.\n'

# %%
# take a look at the dataset
dataset.head()
dataset.describe()
# Out:
#        Work_function  Heat_of_formation  Energy_above_convex_hull   Length(x)  \
# count     275.000000         275.000000                275.000000  275.000000
# mean        4.264700          -1.062837                  0.315639  311.577091
# std         1.530484           0.835387                  0.228956   20.841980
# min         1.347678          -2.984132                  0.000000  262.100000
# 25%         2.792242          -1.646810                  0.162571  294.700000
# 50%         4.537063          -1.079087                  0.268825  312.500000
# 75%         5.349280          -0.483631                  0.424251  324.000000
# max         7.271891           0.957153                  1.138551  378.300000
#
#        Radius_of_orbital_of_metal  Radius_of_orbital_of_support  \
# count                  275.000000                    275.000000
# mean                    65.518545                     54.219636
# std                     16.428133                      5.409809
# min                     38.900000                     48.800000
# 25%                     48.900000                     48.800000
# 50%                     74.600000                     59.600000
# 75%                     79.000000                     59.600000
# max                     86.500000                     59.600000
#
#        Radius_of_orbital_of_termination  Ionisation_potential_of_metal  \
# count                        275.000000                     275.000000
# mean                          45.983636                       6.980777
# std                           13.987596                       0.518915
# min                           36.000000                       6.217000
# 25%                           38.900000                       6.633900
# 50%                           41.400000                       6.825000
# 75%                           41.400000                       7.264100
# max                           86.500000                       7.980000
#
#        Ionisation_potential_of_support  Ionisation_potential_of_termination  \
# count                       275.000000                           275.000000
# mean                         12.891248                            12.719608
# std                           1.639873                             3.765861
# min                          11.260300                             6.217000
# 25%                          11.260300                             7.980000
# 50%                          11.260300                            13.017000
# 75%                          14.534100                            13.618000
# max                          14.534100                            17.422800
#
#        Electronegativity_of_metal  Electronegativity_of_support  \
# count                  275.000000                    275.000000
# mean                     1.601527                      2.794109
# std                      0.333816                      0.245445
# min                      1.220000                      2.550000
# 25%                      1.330000                      2.550000
# 50%                      1.540000                      2.550000
# 75%                      1.630000                      3.040000
# max                      2.360000                      3.040000
#
#        Electronegativity_of_termination  Electron_affinity_of_metal  \
# count                        275.000000                  275.000000
# mean                           2.951018                    0.394964
# std                            0.903641                    0.364981
# min                            1.220000                   -0.500000
# 25%                            2.360000                    0.189000
# 50%                            2.820000                    0.323000
# 75%                            3.440000                    0.749000
# max                            3.980000                    0.894000
#
#        Electron_affinity_of_support  Electron_affinity_of_termination
# count                    275.000000                        275.000000
# mean                       0.598422                          1.755294
# std                        0.667210                          1.099077
# min                       -0.070000                         -0.500000
# 25%                       -0.070000                          0.894000
# 50%                        1.262000                          1.439000
# 75%                        1.262000                          1.827000
# max                        1.262000                          3.401000

# %%
cdf = dataset[['Work_function','Heat_of_formation','Energy_above_convex_hull','Length(x)','Radius_of_orbital_of_metal','Radius_of_orbital_of_support','Radius_of_orbital_of_termination','Ionisation_potential_of_metal','Ionisation_potential_of_support','Ionisation_potential_of_termination','Electronegativity_of_metal','Electronegativity_of_support','Electronegativity_of_termination','Electron_affinity_of_metal','Electron_affinity_of_support','Electron_affinity_of_termination']]
cdf.head(9)
# Out:
#    Work_function  Heat_of_formation  Energy_above_convex_hull  Length(x)  \
# 0       2.271378          -1.345952                  0.242880      330.4
# 1       1.588009          -1.199954                  0.452744      335.0
# 2       2.209840          -0.317344                  0.473693      290.6
# 3       2.463148          -0.594739                  0.327053      285.0
# 4       2.329750          -1.597694                  0.163033      298.9
# 5       2.429486          -1.645322                  0.315790      320.4
# 6       6.244289          -0.755420                  0.290092      293.1
# 7       4.424606          -1.265524                  0.269073      316.7
# 8       4.468438          -1.715968                  0.168985      348.9
#
#    Radius_of_orbital_of_metal  Radius_of_orbital_of_support  \
# 0                        82.9                          59.6
# 1                        53.9                          59.6
# 2                        74.6                          59.6
# 3                        70.2                          48.8
# 4                        48.9                          48.8
# 5                        79.0                          48.8
# 6                        38.9                          59.6
# 7                        78.4                          59.6
# 8                        86.5                          59.6
#
#    Radius_of_orbital_of_termination  Ionisation_potential_of_metal  \
# 0                              41.4                         6.8250
# 1                              41.4                         6.5614
# 2                              41.4                         7.9800
# 3                              41.4                         7.0942
# 4                              41.4                         6.8282
# 5                              41.4                         6.6339
# 6                              36.0                         7.4340
# 7                              36.0                         7.8900
# 8                              36.0                         6.2170
#
#    Ionisation_potential_of_support  Ionisation_potential_of_termination  \
# 0                          11.2603                              13.0170
# 1                          11.2603                              13.0170
# 2                          11.2603                              13.0170
# 3                          14.5341                              13.0170
# 4                          14.5341                              13.0170
# 5                          14.5341                              13.0170
# 6                          11.2603                              17.4228
# 7                          11.2603                              17.4228
# 8                          11.2603                              17.4228
#
#    Electronegativity_of_metal  Electronegativity_of_support  \
# 0                        1.30                          2.55
# 1                        1.36                          2.55
# 2                        2.36                          2.55
# 3                        2.16                          3.04
# 4                        1.54                          3.04
# 5                        1.33                          3.04
# 6                        1.55                          2.55
# 7                        1.50                          2.55
# 8                        1.22                          2.55
#
#    Electronegativity_of_termination  Electron_affinity_of_metal  \
# 0                              2.82                       0.178
# 1                              2.82                       0.189
# 2                              2.82                       0.816
# 3                              2.82                       0.749
# 4                              2.82                       0.087
# 5                              2.82                       0.427
# 6                              3.98                      -0.500
# 7                              3.98                       0.323
# 8                              3.98                       0.308
#
#    Electron_affinity_of_support  Electron_affinity_of_termination
# 0                         1.262                             1.827
# 1                         1.262                             1.827
# 2                         1.262                             1.827
# 3                        -0.070                             1.827
# 4                        -0.070                             1.827
# 5                        -0.070                             1.827
# 6                         1.262                             3.401
# 7                         1.262                             3.401
# 8                         1.262                             3.401

# %%
###################### Simple Linear Regression

regr = LinearRegression()

# Assuming 'HoF', 'E_Hull', 'Length(x)', ..., are your features
features = ['Heat_of_formation','Length(x)','Radius_of_orbital_of_metal','Radius_of_orbital_of_support','Radius_of_orbital_of_termination', 'Ionisation_potential_of_metal','Ionisation_potential_of_support','Ionisation_potential_of_termination', 'Electronegativity_of_metal','Electronegativity_of_support','Electronegativity_of_termination','Electron_affinity_of_metal','Electron_affinity_of_support','Electron_affinity_of_termination']
target = ['Energy_above_convex_hull']

# Split the data into train and test sets
train, test = train_test_split(dataset, test_size=0.2, random_state=42)

# Train set
train_x = np.asanyarray(train[features])
train_y = np.asanyarray(train[target])

# Test set
test_x = np.asanyarray(test[features])
test_y = np.asanyarray(test[target])

# Create and train the Linear Regression model
regr.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat = regr.predict(train_x)
test_y_hat = regr.predict(test_x)

# Calculate MSE, MAE, and R2 for the train set
train_mse = mean_squared_error(train_y, train_y_hat)
train_mae = mean_absolute_error(train_y, train_y_hat)
train_r2 = r2_score(train_y, train_y_hat)

# Calculate MSE, MAE, and R2 for the test set
test_mse = mean_squared_error(test_y, test_y_hat)
test_mae = mean_absolute_error(test_y, test_y_hat)
test_r2 = r2_score(test_y, test_y_hat)

# Print the results
print('Linear Regression\n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse)
print("MAE: %.2f" % train_mae)
print("R2 Score: %.2f" % train_r2)
print('LinearRegression\n')
print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse)
print("MAE: %.2f" % test_mae)
print("R2 Score: %.2f" % test_r2)
# Out:
# Linear Regression
#
# Train set metrics:
# MAE: 0.11
# R2 Score: 0.58
# LinearRegression
#
#
# Test set metrics:
# MAE: 0.11
# R2 Score: 0.65

# %%
####################### LASSO Regression


# Initialize LASSO model
regr1 = Lasso()
# Create and train the LASSO Regression model
regr1.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat1 = regr1.predict(train_x)
test_y_hat1 = regr1.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse1 = mean_squared_error(train_y, train_y_hat1)
train_mae1 = mean_absolute_error(train_y, train_y_hat1)
train_r2_1 = r2_score(train_y, train_y_hat1)

# Calculate MSE, MAE, and R2 for the test set
test_mse1 = mean_squared_error(test_y, test_y_hat1)
test_mae1 = mean_absolute_error(test_y, test_y_hat1)
test_r2_1 = r2_score(test_y, test_y_hat1)

# Print the results
print('LASSO Regression')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse1)
print("MAE: %.2f" % train_mae1)
print("R2 Score: %.2f" % train_r2_1)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse1)
print("MAE: %.2f" % test_mae1)
print("R2 Score: %.2f" % test_r2_1)
# Out:
# LASSO Regression
# Train set metrics:
# MAE: 0.16
# R2 Score: 0.15
#
# Test set metrics:
# MAE: 0.18
# R2 Score: 0.14

# %%
####################### Ridge Regression



# Initialize Ridge Regression
regr2 = Ridge()
# Create and train the Ridge Regression model
regr2.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat2 = regr2.predict(train_x)
test_y_hat2 = regr2.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse2 = mean_squared_error(train_y, train_y_hat2)
train_mae2 = mean_absolute_error(train_y, train_y_hat2)
train_r2_2 = r2_score(train_y, train_y_hat2)

# Calculate MSE, MAE, and R2 for the test set
test_mse2 = mean_squared_error(test_y, test_y_hat2)
test_mae2 = mean_absolute_error(test_y, test_y_hat2)
test_r2_2 = r2_score(test_y, test_y_hat2)

# Print the results
print('Ridge Regression\n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse2)
print("MAE: %.2f" % train_mae2)
print("R2 Score: %.2f" % train_r2_2)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse2)
print("MAE: %.2f" % test_mae2)
print("R2 Score: %.2f" % test_r2_2)
# Out:
# Ridge Regression
#
# Train set metrics:
# MAE: 0.11
# R2 Score: 0.58
#
# Test set metrics:
# MAE: 0.11
# R2 Score: 0.65

# %%
###################### Random Forest Regression



# Initialize Random Forest Regression
regr3 = RandomForestRegressor()
# Create and train the Random Forest Regression model
regr3.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat3 = regr3.predict(train_x)
test_y_hat3 = regr3.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse3 = mean_squared_error(train_y, train_y_hat3)
train_mae3 = mean_absolute_error(train_y, train_y_hat3)
train_r2_3 = r2_score(train_y, train_y_hat3)

# Calculate MSE, MAE, and R2 for the test set
test_mse3 = mean_squared_error(test_y, test_y_hat3)
test_mae3 = mean_absolute_error(test_y, test_y_hat3)
test_r2_3 = r2_score(test_y, test_y_hat3)

# Print the results
print('Random Forest Regression \n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse3)
print("MAE: %.2f" % train_mae3)
print("R2 Score: %.2f" % train_r2_3)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse3)
print("MAE: %.2f" % test_mae3)
print("R2 Score: %.2f" % test_r2_3)
# Out:
# /home/azaan/anaconda3/envs/data_science/lib/python3.9/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest Regression
#
# Train set metrics:
# MAE: 0.03
# R2 Score: 0.96
#
# Test set metrics:
# MAE: 0.08
# R2 Score: 0.79

# %% [markdown]
# ################## Neural Network Regression

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam, RMSprop, Nadam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Preprocessing
dataset_columns = dataset.columns
columns_to_exclude = ['Formula', 'M', 'X', 'T', 'Work_function', 'Energy_above_convex_hull',]
predictors = dataset.drop(columns=columns_to_exclude)
target = dataset['Energy_above_convex_hull']
predictors_norm = (predictors - predictors.mean()) / predictors.std()

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.2, random_state=42)

# Get the number of input features
n_cols = predictors_norm.shape[1]

def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(1024, activation='relu', input_shape=(n_cols,), kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    model.add(Dense(512, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Dense(256, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Dense(128, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Dense(64, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    
    model.add(Dense(1))
    optimizer = Adadelta(learning_rate=1.0)
    
    model.compile(optimizer=optimizer, loss='mae')
    return model

# Build the model
model = regression_model()

# Early stopping and learning rate reduction callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1)

# Fit the model
history = model.fit(X_train, y_train, 
                    batch_size=32, 
                    validation_split=0.2, 
                    epochs=1000, 
                    verbose=1, 
                    callbacks=[early_stopping, reduce_lr])

# Make predictions on the training set
train_predictions = model.predict(X_train)

# Make predictions on the testing set
test_predictions = model.predict(X_test)

# Calculate R2 score for training and testing sets
r2_train = r2_score(y_train, train_predictions)
r2_test = r2_score(y_test, test_predictions)

# Calculate MAE for training and testing sets
mae_train = mean_absolute_error(y_train, train_predictions)
mae_test = mean_absolute_error(y_test, test_predictions)

# Print the results
print(f'Training R2 Score: {r2_train}')
print(f'Testing R2 Score: {r2_test}')
print(f'Training Mean Absolute Error: {mae_train}')
print(f'Testing Mean Absolute Error: {mae_test}')
# Out:
# /home/azaan/anaconda3/envs/data_science/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-10-06 13:38:09.028707: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:38:09.035620: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:38:09.035853: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:38:09.037846: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:38:09.038866: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:38:09.039566: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:38:09.095139: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:38:09.095467: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:38:09.095645: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:38:09.095789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 212 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 960M, pci bus id: 0000:01:00.0, compute capability: 5.0
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728203893.252852  287171 service.cc:145] XLA service 0x70b3d4014da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728203893.252884  287171 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 960M, Compute Capability 5.0
# 2024-10-06 13:38:13.369121: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-06 13:38:13.886002: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 1:07 14s/step - loss: 14.1308
# I0000 00:00:1728203903.025159  287171 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - loss: 14.0937 - val_loss: 13.1489 - learning_rate: 1.0000
# Epoch 2/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.8778 - val_loss: 12.9533 - learning_rate: 1.0000
# Epoch 3/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 13.4452 - val_loss: 12.7054 - learning_rate: 1.0000
# Epoch 4/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.1068 - val_loss: 12.4751 - learning_rate: 1.0000
# Epoch 5/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.8189 - val_loss: 12.2860 - learning_rate: 1.0000
# Epoch 6/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.5658 - val_loss: 12.0685 - learning_rate: 1.0000
# Epoch 7/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.3528 - val_loss: 11.8970 - learning_rate: 1.0000
# Epoch 8/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.1054 - val_loss: 11.6732 - learning_rate: 1.0000
# Epoch 9/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.8657 - val_loss: 11.4443 - learning_rate: 1.0000
# Epoch 10/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.6536 - val_loss: 11.2245 - learning_rate: 1.0000
# Epoch 11/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.3411 - val_loss: 10.9599 - learning_rate: 1.0000
# Epoch 12/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.1579 - val_loss: 10.7424 - learning_rate: 1.0000
# Epoch 13/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.8903 - val_loss: 10.5472 - learning_rate: 1.0000
# Epoch 14/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.6535 - val_loss: 10.2913 - learning_rate: 1.0000
# Epoch 15/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.4582 - val_loss: 10.0601 - learning_rate: 1.0000
# Epoch 16/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.1598 - val_loss: 9.8320 - learning_rate: 1.0000
# Epoch 17/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.9196 - val_loss: 9.5951 - learning_rate: 1.0000
# Epoch 18/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.6389 - val_loss: 9.3667 - learning_rate: 1.0000
# Epoch 19/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4558 - val_loss: 9.1081 - learning_rate: 1.0000
# Epoch 20/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.1775 - val_loss: 8.8744 - learning_rate: 1.0000
# Epoch 21/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8902 - val_loss: 8.6253 - learning_rate: 1.0000
# Epoch 22/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.6636 - val_loss: 8.3852 - learning_rate: 1.0000
# Epoch 23/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.4156 - val_loss: 8.1475 - learning_rate: 1.0000
# Epoch 24/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1698 - val_loss: 7.8871 - learning_rate: 1.0000
# Epoch 25/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.9249 - val_loss: 7.6503 - learning_rate: 1.0000
# Epoch 26/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.6427 - val_loss: 7.3895 - learning_rate: 1.0000
# Epoch 27/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.3932 - val_loss: 7.1386 - learning_rate: 1.0000
# Epoch 28/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.1328 - val_loss: 6.9028 - learning_rate: 1.0000
# Epoch 29/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.8940 - val_loss: 6.6621 - learning_rate: 1.0000
# Epoch 30/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6495 - val_loss: 6.3999 - learning_rate: 1.0000
# Epoch 31/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.4137 - val_loss: 6.2124 - learning_rate: 1.0000
# Epoch 32/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.1206 - val_loss: 5.9550 - learning_rate: 1.0000
# Epoch 33/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.9072 - val_loss: 5.7183 - learning_rate: 1.0000
# Epoch 34/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.7080 - val_loss: 5.4886 - learning_rate: 1.0000
# Epoch 35/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4780 - val_loss: 5.2704 - learning_rate: 1.0000
# Epoch 36/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.2564 - val_loss: 5.0436 - learning_rate: 1.0000
# Epoch 37/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0329 - val_loss: 4.8441 - learning_rate: 1.0000
# Epoch 38/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.8342 - val_loss: 4.6443 - learning_rate: 1.0000
# Epoch 39/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.6281 - val_loss: 4.4724 - learning_rate: 1.0000
# Epoch 40/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.4429 - val_loss: 4.2577 - learning_rate: 1.0000
# Epoch 41/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2525 - val_loss: 4.1166 - learning_rate: 1.0000
# Epoch 42/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0537 - val_loss: 3.9246 - learning_rate: 1.0000
# Epoch 43/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8975 - val_loss: 3.7477 - learning_rate: 1.0000
# Epoch 44/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7207 - val_loss: 3.5858 - learning_rate: 1.0000
# Epoch 45/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5622 - val_loss: 3.4393 - learning_rate: 1.0000
# Epoch 46/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4284 - val_loss: 3.2785 - learning_rate: 1.0000
# Epoch 47/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2617 - val_loss: 3.1554 - learning_rate: 1.0000
# Epoch 48/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1310 - val_loss: 3.0062 - learning_rate: 1.0000
# Epoch 49/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9829 - val_loss: 2.8753 - learning_rate: 1.0000
# Epoch 50/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8402 - val_loss: 2.7414 - learning_rate: 1.0000
# Epoch 51/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7023 - val_loss: 2.6286 - learning_rate: 1.0000
# Epoch 52/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5833 - val_loss: 2.5060 - learning_rate: 1.0000
# Epoch 53/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4624 - val_loss: 2.4024 - learning_rate: 1.0000
# Epoch 54/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3645 - val_loss: 2.2841 - learning_rate: 1.0000
# Epoch 55/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2364 - val_loss: 2.1806 - learning_rate: 1.0000
# Epoch 56/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1479 - val_loss: 2.0798 - learning_rate: 1.0000
# Epoch 57/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0474 - val_loss: 2.0096 - learning_rate: 1.0000
# Epoch 58/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9517 - val_loss: 1.9298 - learning_rate: 1.0000
# Epoch 59/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8863 - val_loss: 1.8488 - learning_rate: 1.0000
# Epoch 60/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7866 - val_loss: 1.8089 - learning_rate: 1.0000
# Epoch 61/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7405 - val_loss: 1.6881 - learning_rate: 1.0000
# Epoch 62/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6632 - val_loss: 1.6338 - learning_rate: 1.0000
# Epoch 63/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5643 - val_loss: 1.5680 - learning_rate: 1.0000
# Epoch 64/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5124 - val_loss: 1.5085 - learning_rate: 1.0000
# Epoch 65/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4512 - val_loss: 1.4442 - learning_rate: 1.0000
# Epoch 66/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3723 - val_loss: 1.3775 - learning_rate: 1.0000
# Epoch 67/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3181 - val_loss: 1.3210 - learning_rate: 1.0000
# Epoch 68/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2759 - val_loss: 1.2706 - learning_rate: 1.0000
# Epoch 69/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2114 - val_loss: 1.2283 - learning_rate: 1.0000
# Epoch 70/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1703 - val_loss: 1.1756 - learning_rate: 1.0000
# Epoch 71/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1157 - val_loss: 1.1288 - learning_rate: 1.0000
# Epoch 72/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0894 - val_loss: 1.0987 - learning_rate: 1.0000
# Epoch 73/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0558 - val_loss: 1.0591 - learning_rate: 1.0000
# Epoch 74/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0001 - val_loss: 1.0300 - learning_rate: 1.0000
# Epoch 75/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9699 - val_loss: 0.9928 - learning_rate: 1.0000
# Epoch 76/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9316 - val_loss: 0.9565 - learning_rate: 1.0000
# Epoch 77/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9076 - val_loss: 0.9176 - learning_rate: 1.0000
# Epoch 78/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8673 - val_loss: 0.9024 - learning_rate: 1.0000
# Epoch 79/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8420 - val_loss: 0.8556 - learning_rate: 1.0000
# Epoch 80/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8005 - val_loss: 0.8307 - learning_rate: 1.0000
# Epoch 81/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7678 - val_loss: 0.7993 - learning_rate: 1.0000
# Epoch 82/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7293 - val_loss: 0.7711 - learning_rate: 1.0000
# Epoch 83/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7050 - val_loss: 0.7497 - learning_rate: 1.0000
# Epoch 84/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6909 - val_loss: 0.7450 - learning_rate: 1.0000
# Epoch 85/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6810 - val_loss: 0.7105 - learning_rate: 1.0000
# Epoch 86/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6450 - val_loss: 0.6805 - learning_rate: 1.0000
# Epoch 87/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6212 - val_loss: 0.6553 - learning_rate: 1.0000
# Epoch 88/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5967 - val_loss: 0.6603 - learning_rate: 1.0000
# Epoch 89/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5673 - val_loss: 0.6361 - learning_rate: 1.0000
# Epoch 90/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5564 - val_loss: 0.6295 - learning_rate: 1.0000
# Epoch 91/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5620 - val_loss: 0.6012 - learning_rate: 1.0000
# Epoch 92/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5237 - val_loss: 0.5777 - learning_rate: 1.0000
# Epoch 93/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5203 - val_loss: 0.5670 - learning_rate: 1.0000
# Epoch 94/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5147 - val_loss: 0.5412 - learning_rate: 1.0000
# Epoch 95/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5066 - val_loss: 0.5381 - learning_rate: 1.0000
# Epoch 96/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4859 - val_loss: 0.5132 - learning_rate: 1.0000
# Epoch 97/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4645 - val_loss: 0.5086 - learning_rate: 1.0000
# Epoch 98/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4506 - val_loss: 0.4918 - learning_rate: 1.0000
# Epoch 99/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4339 - val_loss: 0.4942 - learning_rate: 1.0000
# Epoch 100/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4151 - val_loss: 0.4842 - learning_rate: 1.0000
# Epoch 101/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4132 - val_loss: 0.4590 - learning_rate: 1.0000
# Epoch 102/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4193 - val_loss: 0.4555 - learning_rate: 1.0000
# Epoch 103/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4041 - val_loss: 0.4595 - learning_rate: 1.0000
# Epoch 104/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4049 - val_loss: 0.4412 - learning_rate: 1.0000
# Epoch 105/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3958 - val_loss: 0.4091 - learning_rate: 1.0000
# Epoch 106/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3984 - val_loss: 0.3967 - learning_rate: 1.0000
# Epoch 107/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3773 - val_loss: 0.3941 - learning_rate: 1.0000
# Epoch 108/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3635 - val_loss: 0.3886 - learning_rate: 1.0000
# Epoch 109/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3399 - val_loss: 0.3949 - learning_rate: 1.0000
# Epoch 110/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3438 - val_loss: 0.3982 - learning_rate: 1.0000
# Epoch 111/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3259 - val_loss: 0.3737 - learning_rate: 1.0000
# Epoch 112/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3147 - val_loss: 0.3707 - learning_rate: 1.0000
# Epoch 113/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3197 - val_loss: 0.3714 - learning_rate: 1.0000
# Epoch 114/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3404 - val_loss: 0.3499 - learning_rate: 1.0000
# Epoch 115/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3254 - val_loss: 0.3427 - learning_rate: 1.0000
# Epoch 116/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3108 - val_loss: 0.3434 - learning_rate: 1.0000
# Epoch 117/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2897 - val_loss: 0.3335 - learning_rate: 1.0000
# Epoch 118/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3054 - val_loss: 0.3436 - learning_rate: 1.0000
# Epoch 119/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2999 - val_loss: 0.3466 - learning_rate: 1.0000
# Epoch 120/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2770 - val_loss: 0.3650 - learning_rate: 1.0000
# Epoch 121/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3222 - val_loss: 0.3318 - learning_rate: 1.0000
# Epoch 122/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3083 - val_loss: 0.3111 - learning_rate: 1.0000
# Epoch 123/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2995 - val_loss: 0.3241 - learning_rate: 1.0000
# Epoch 124/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2811 - val_loss: 0.3152 - learning_rate: 1.0000
# Epoch 125/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2747 - val_loss: 0.2855 - learning_rate: 1.0000
# Epoch 126/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2802 - val_loss: 0.2791 - learning_rate: 1.0000
# Epoch 127/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2736 - val_loss: 0.2942 - learning_rate: 1.0000
# Epoch 128/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2604 - val_loss: 0.3329 - learning_rate: 1.0000
# Epoch 129/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2680 - val_loss: 0.2976 - learning_rate: 1.0000
# Epoch 130/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2531 - val_loss: 0.2723 - learning_rate: 1.0000
# Epoch 131/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2433 - val_loss: 0.2721 - learning_rate: 1.0000
# Epoch 132/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2272 - val_loss: 0.2580 - learning_rate: 1.0000
# Epoch 133/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2294 - val_loss: 0.2535 - learning_rate: 1.0000
# Epoch 134/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2382 - val_loss: 0.2315 - learning_rate: 1.0000
# Epoch 135/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2394 - val_loss: 0.2517 - learning_rate: 1.0000
# Epoch 136/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2473 - val_loss: 0.2362 - learning_rate: 1.0000
# Epoch 137/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2417 - val_loss: 0.2384 - learning_rate: 1.0000
# Epoch 138/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2356 - val_loss: 0.2633 - learning_rate: 1.0000
# Epoch 139/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2364 - val_loss: 0.2511 - learning_rate: 1.0000
# Epoch 140/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2327 - val_loss: 0.2165 - learning_rate: 1.0000
# Epoch 141/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2207 - val_loss: 0.2239 - learning_rate: 1.0000
# Epoch 142/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2202 - val_loss: 0.2556 - learning_rate: 1.0000
# Epoch 143/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2245 - val_loss: 0.2271 - learning_rate: 1.0000
# Epoch 144/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2086 - val_loss: 0.2516 - learning_rate: 1.0000
# Epoch 145/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2120 - val_loss: 0.2259 - learning_rate: 1.0000
# Epoch 146/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2118 - val_loss: 0.2303 - learning_rate: 1.0000
# Epoch 147/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2154 - val_loss: 0.2106 - learning_rate: 1.0000
# Epoch 148/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2225 - val_loss: 0.2290 - learning_rate: 1.0000
# Epoch 149/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2154 - val_loss: 0.2157 - learning_rate: 1.0000
# Epoch 150/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2088 - val_loss: 0.2110 - learning_rate: 1.0000
# Epoch 151/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2220 - val_loss: 0.2292 - learning_rate: 1.0000
# Epoch 152/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2093 - val_loss: 0.2545 - learning_rate: 1.0000
# Epoch 153/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2203 - val_loss: 0.2651 - learning_rate: 1.0000
# Epoch 154/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2234 - val_loss: 0.2119 - learning_rate: 1.0000
# Epoch 155/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2140 - val_loss: 0.2557 - learning_rate: 1.0000
# Epoch 156/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2101 - val_loss: 0.1934 - learning_rate: 1.0000
# Epoch 157/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1966 - val_loss: 0.2092 - learning_rate: 1.0000
# Epoch 158/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2045 - val_loss: 0.1927 - learning_rate: 1.0000
# Epoch 159/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2073 - val_loss: 0.1784 - learning_rate: 1.0000
# Epoch 160/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1958 - val_loss: 0.2173 - learning_rate: 1.0000
# Epoch 161/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1917 - val_loss: 0.2116 - learning_rate: 1.0000
# Epoch 162/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1914 - val_loss: 0.2013 - learning_rate: 1.0000
# Epoch 163/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1730 - val_loss: 0.2350 - learning_rate: 1.0000
# Epoch 164/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2145 - val_loss: 0.2246 - learning_rate: 1.0000
# Epoch 165/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1991 - val_loss: 0.1992 - learning_rate: 1.0000
# Epoch 166/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1778 - val_loss: 0.2210 - learning_rate: 1.0000
# Epoch 167/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1958 - val_loss: 0.1864 - learning_rate: 1.0000
# Epoch 168/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1814 - val_loss: 0.2012 - learning_rate: 1.0000
# Epoch 169/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1846
# Epoch 169: ReduceLROnPlateau reducing learning rate to 0.5.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1819 - val_loss: 0.1954 - learning_rate: 1.0000
# Epoch 170/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1725 - val_loss: 0.1828 - learning_rate: 0.5000
# Epoch 171/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1577 - val_loss: 0.1697 - learning_rate: 0.5000
# Epoch 172/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1511 - val_loss: 0.1898 - learning_rate: 0.5000
# Epoch 173/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1416 - val_loss: 0.1835 - learning_rate: 0.5000
# Epoch 174/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1676 - val_loss: 0.1873 - learning_rate: 0.5000
# Epoch 175/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1591 - val_loss: 0.1882 - learning_rate: 0.5000
# Epoch 176/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1567 - val_loss: 0.1973 - learning_rate: 0.5000
# Epoch 177/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1557 - val_loss: 0.1933 - learning_rate: 0.5000
# Epoch 178/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1472 - val_loss: 0.1984 - learning_rate: 0.5000
# Epoch 179/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1438 - val_loss: 0.1960 - learning_rate: 0.5000
# Epoch 180/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1351 - val_loss: 0.1915 - learning_rate: 0.5000
# Epoch 181/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1409
# Epoch 181: ReduceLROnPlateau reducing learning rate to 0.25.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1413 - val_loss: 0.2007 - learning_rate: 0.5000
# Epoch 182/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1342 - val_loss: 0.1909 - learning_rate: 0.2500
# Epoch 183/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1426 - val_loss: 0.1860 - learning_rate: 0.2500
# Epoch 184/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1294 - val_loss: 0.1830 - learning_rate: 0.2500
# Epoch 185/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1242 - val_loss: 0.1936 - learning_rate: 0.2500
# Epoch 186/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1370 - val_loss: 0.1841 - learning_rate: 0.2500
# Epoch 187/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1241 - val_loss: 0.1802 - learning_rate: 0.2500
# Epoch 188/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1288 - val_loss: 0.1825 - learning_rate: 0.2500
# Epoch 189/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1191 - val_loss: 0.1817 - learning_rate: 0.2500
# Epoch 190/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1184 - val_loss: 0.1835 - learning_rate: 0.2500
# Epoch 191/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1165
# Epoch 191: ReduceLROnPlateau reducing learning rate to 0.125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1209 - val_loss: 0.1804 - learning_rate: 0.2500
# Epoch 192/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1255 - val_loss: 0.1829 - learning_rate: 0.1250
# Epoch 193/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1165 - val_loss: 0.1792 - learning_rate: 0.1250
# Epoch 194/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1163 - val_loss: 0.1803 - learning_rate: 0.1250
# Epoch 195/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1171 - val_loss: 0.1780 - learning_rate: 0.1250
# Epoch 196/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1166 - val_loss: 0.1835 - learning_rate: 0.1250
# Epoch 197/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1237 - val_loss: 0.1784 - learning_rate: 0.1250
# Epoch 198/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1211 - val_loss: 0.1717 - learning_rate: 0.1250
# Epoch 199/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1196 - val_loss: 0.1736 - learning_rate: 0.1250
# Epoch 200/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1249 - val_loss: 0.1815 - learning_rate: 0.1250
# Epoch 201/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1138 - val_loss: 0.1692 - learning_rate: 0.1250
# Epoch 202/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1099 - val_loss: 0.1714 - learning_rate: 0.1250
# Epoch 203/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1149 - val_loss: 0.1701 - learning_rate: 0.1250
# Epoch 204/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1091 - val_loss: 0.1671 - learning_rate: 0.1250
# Epoch 205/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1127 - val_loss: 0.1731 - learning_rate: 0.1250
# Epoch 206/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1075 - val_loss: 0.1716 - learning_rate: 0.1250
# Epoch 207/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1155 - val_loss: 0.1728 - learning_rate: 0.1250
# Epoch 208/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1127 - val_loss: 0.1669 - learning_rate: 0.1250
# Epoch 209/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1133 - val_loss: 0.1660 - learning_rate: 0.1250
# Epoch 210/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1055 - val_loss: 0.1727 - learning_rate: 0.1250
# Epoch 211/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1135 - val_loss: 0.1749 - learning_rate: 0.1250
# Epoch 212/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1158 - val_loss: 0.1633 - learning_rate: 0.1250
# Epoch 213/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1263 - val_loss: 0.1634 - learning_rate: 0.1250
# Epoch 214/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1193 - val_loss: 0.1601 - learning_rate: 0.1250
# Epoch 215/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1074 - val_loss: 0.1575 - learning_rate: 0.1250
# Epoch 216/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1010 - val_loss: 0.1623 - learning_rate: 0.1250
# Epoch 217/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1114 - val_loss: 0.1613 - learning_rate: 0.1250
# Epoch 218/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1033 - val_loss: 0.1587 - learning_rate: 0.1250
# Epoch 219/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1076 - val_loss: 0.1554 - learning_rate: 0.1250
# Epoch 220/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1048 - val_loss: 0.1541 - learning_rate: 0.1250
# Epoch 221/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1133 - val_loss: 0.1538 - learning_rate: 0.1250
# Epoch 222/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1139 - val_loss: 0.1583 - learning_rate: 0.1250
# Epoch 223/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1090 - val_loss: 0.1566 - learning_rate: 0.1250
# Epoch 224/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0987 - val_loss: 0.1556 - learning_rate: 0.1250
# Epoch 225/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1049 - val_loss: 0.1554 - learning_rate: 0.1250
# Epoch 226/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1010 - val_loss: 0.1521 - learning_rate: 0.1250
# Epoch 227/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1087 - val_loss: 0.1481 - learning_rate: 0.1250
# Epoch 228/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1078 - val_loss: 0.1438 - learning_rate: 0.1250
# Epoch 229/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1138 - val_loss: 0.1444 - learning_rate: 0.1250
# Epoch 230/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1083 - val_loss: 0.1419 - learning_rate: 0.1250
# Epoch 231/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1043 - val_loss: 0.1472 - learning_rate: 0.1250
# Epoch 232/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0950 - val_loss: 0.1390 - learning_rate: 0.1250
# Epoch 233/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1021 - val_loss: 0.1454 - learning_rate: 0.1250
# Epoch 234/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1001 - val_loss: 0.1424 - learning_rate: 0.1250
# Epoch 235/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1036 - val_loss: 0.1473 - learning_rate: 0.1250
# Epoch 236/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0951 - val_loss: 0.1433 - learning_rate: 0.1250
# Epoch 237/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1084 - val_loss: 0.1446 - learning_rate: 0.1250
# Epoch 238/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0943 - val_loss: 0.1447 - learning_rate: 0.1250
# Epoch 239/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1031 - val_loss: 0.1340 - learning_rate: 0.1250
# Epoch 240/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0997 - val_loss: 0.1386 - learning_rate: 0.1250
# Epoch 241/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1051 - val_loss: 0.1530 - learning_rate: 0.1250
# Epoch 242/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0993 - val_loss: 0.1505 - learning_rate: 0.1250
# Epoch 243/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1012 - val_loss: 0.1416 - learning_rate: 0.1250
# Epoch 244/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0989 - val_loss: 0.1443 - learning_rate: 0.1250
# Epoch 245/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1022 - val_loss: 0.1411 - learning_rate: 0.1250
# Epoch 246/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1059 - val_loss: 0.1413 - learning_rate: 0.1250
# Epoch 247/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0989 - val_loss: 0.1397 - learning_rate: 0.1250
# Epoch 248/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0996 - val_loss: 0.1402 - learning_rate: 0.1250
# Epoch 249/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0958
# Epoch 249: ReduceLROnPlateau reducing learning rate to 0.0625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0960 - val_loss: 0.1379 - learning_rate: 0.1250
# Epoch 250/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0967 - val_loss: 0.1391 - learning_rate: 0.0625
# Epoch 251/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1139 - val_loss: 0.1371 - learning_rate: 0.0625
# Epoch 252/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0963 - val_loss: 0.1360 - learning_rate: 0.0625
# Epoch 253/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0990 - val_loss: 0.1345 - learning_rate: 0.0625
# Epoch 254/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1007 - val_loss: 0.1369 - learning_rate: 0.0625
# Epoch 255/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0945 - val_loss: 0.1368 - learning_rate: 0.0625
# Epoch 256/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0979 - val_loss: 0.1367 - learning_rate: 0.0625
# Epoch 257/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0989 - val_loss: 0.1360 - learning_rate: 0.0625
# Epoch 258/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0882 - val_loss: 0.1362 - learning_rate: 0.0625
# Epoch 259/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0988
# Epoch 259: ReduceLROnPlateau reducing learning rate to 0.03125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0951 - val_loss: 0.1353 - learning_rate: 0.0625
# Epoch 260/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0927 - val_loss: 0.1339 - learning_rate: 0.0312
# Epoch 261/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0916 - val_loss: 0.1317 - learning_rate: 0.0312
# Epoch 262/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0933 - val_loss: 0.1314 - learning_rate: 0.0312
# Epoch 263/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1121 - val_loss: 0.1316 - learning_rate: 0.0312
# Epoch 264/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0912 - val_loss: 0.1300 - learning_rate: 0.0312
# Epoch 265/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0860 - val_loss: 0.1301 - learning_rate: 0.0312
# Epoch 266/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0937 - val_loss: 0.1281 - learning_rate: 0.0312
# Epoch 267/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0953 - val_loss: 0.1277 - learning_rate: 0.0312
# Epoch 268/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0904 - val_loss: 0.1291 - learning_rate: 0.0312
# Epoch 269/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1035 - val_loss: 0.1292 - learning_rate: 0.0312
# Epoch 270/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0982 - val_loss: 0.1283 - learning_rate: 0.0312
# Epoch 271/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0939 - val_loss: 0.1288 - learning_rate: 0.0312
# Epoch 272/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0928 - val_loss: 0.1274 - learning_rate: 0.0312
# Epoch 273/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0837 - val_loss: 0.1264 - learning_rate: 0.0312
# Epoch 274/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1015 - val_loss: 0.1264 - learning_rate: 0.0312
# Epoch 275/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0940 - val_loss: 0.1252 - learning_rate: 0.0312
# Epoch 276/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0823 - val_loss: 0.1247 - learning_rate: 0.0312
# Epoch 277/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0949 - val_loss: 0.1257 - learning_rate: 0.0312
# Epoch 278/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0954 - val_loss: 0.1230 - learning_rate: 0.0312
# Epoch 279/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1043 - val_loss: 0.1243 - learning_rate: 0.0312
# Epoch 280/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0908 - val_loss: 0.1238 - learning_rate: 0.0312
# Epoch 281/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0877 - val_loss: 0.1217 - learning_rate: 0.0312
# Epoch 282/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1005 - val_loss: 0.1226 - learning_rate: 0.0312
# Epoch 283/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0948 - val_loss: 0.1244 - learning_rate: 0.0312
# Epoch 284/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0853 - val_loss: 0.1209 - learning_rate: 0.0312
# Epoch 285/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0965 - val_loss: 0.1213 - learning_rate: 0.0312
# Epoch 286/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0984 - val_loss: 0.1231 - learning_rate: 0.0312
# Epoch 287/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0885 - val_loss: 0.1218 - learning_rate: 0.0312
# Epoch 288/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0908 - val_loss: 0.1220 - learning_rate: 0.0312
# Epoch 289/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0933 - val_loss: 0.1224 - learning_rate: 0.0312
# Epoch 290/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0882 - val_loss: 0.1206 - learning_rate: 0.0312
# Epoch 291/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0883 - val_loss: 0.1226 - learning_rate: 0.0312
# Epoch 292/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0838 - val_loss: 0.1247 - learning_rate: 0.0312
# Epoch 293/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0822 - val_loss: 0.1221 - learning_rate: 0.0312
# Epoch 294/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0963 - val_loss: 0.1222 - learning_rate: 0.0312
# Epoch 295/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0913 - val_loss: 0.1210 - learning_rate: 0.0312
# Epoch 296/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0879 - val_loss: 0.1203 - learning_rate: 0.0312
# Epoch 297/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0916 - val_loss: 0.1207 - learning_rate: 0.0312
# Epoch 298/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0873 - val_loss: 0.1201 - learning_rate: 0.0312
# Epoch 299/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0995 - val_loss: 0.1202 - learning_rate: 0.0312
# Epoch 300/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0917 - val_loss: 0.1224 - learning_rate: 0.0312
# Epoch 301/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0885 - val_loss: 0.1214 - learning_rate: 0.0312
# Epoch 302/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0835 - val_loss: 0.1217 - learning_rate: 0.0312
# Epoch 303/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0923 - val_loss: 0.1208 - learning_rate: 0.0312
# Epoch 304/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0872 - val_loss: 0.1217 - learning_rate: 0.0312
# Epoch 305/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0829 - val_loss: 0.1192 - learning_rate: 0.0312
# Epoch 306/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0979 - val_loss: 0.1166 - learning_rate: 0.0312
# Epoch 307/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0799 - val_loss: 0.1175 - learning_rate: 0.0312
# Epoch 308/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0830 - val_loss: 0.1172 - learning_rate: 0.0312
# Epoch 309/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0822 - val_loss: 0.1167 - learning_rate: 0.0312
# Epoch 310/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0938 - val_loss: 0.1182 - learning_rate: 0.0312
# Epoch 311/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0872 - val_loss: 0.1167 - learning_rate: 0.0312
# Epoch 312/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0984 - val_loss: 0.1163 - learning_rate: 0.0312
# Epoch 313/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0832 - val_loss: 0.1175 - learning_rate: 0.0312
# Epoch 314/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0804 - val_loss: 0.1167 - learning_rate: 0.0312
# Epoch 315/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0898 - val_loss: 0.1144 - learning_rate: 0.0312
# Epoch 316/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0882 - val_loss: 0.1134 - learning_rate: 0.0312
# Epoch 317/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0859 - val_loss: 0.1146 - learning_rate: 0.0312
# Epoch 318/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0893 - val_loss: 0.1181 - learning_rate: 0.0312
# Epoch 319/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0849 - val_loss: 0.1206 - learning_rate: 0.0312
# Epoch 320/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0908 - val_loss: 0.1173 - learning_rate: 0.0312
# Epoch 321/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0813 - val_loss: 0.1171 - learning_rate: 0.0312
# Epoch 322/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0834 - val_loss: 0.1166 - learning_rate: 0.0312
# Epoch 323/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0933 - val_loss: 0.1189 - learning_rate: 0.0312
# Epoch 324/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0888 - val_loss: 0.1181 - learning_rate: 0.0312
# Epoch 325/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0926 - val_loss: 0.1159 - learning_rate: 0.0312
# Epoch 326/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0805
# Epoch 326: ReduceLROnPlateau reducing learning rate to 0.015625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0993 - val_loss: 0.1142 - learning_rate: 0.0312
# Epoch 327/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0967 - val_loss: 0.1147 - learning_rate: 0.0156
# Epoch 328/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0853 - val_loss: 0.1164 - learning_rate: 0.0156
# Epoch 329/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0852 - val_loss: 0.1155 - learning_rate: 0.0156
# Epoch 330/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0830 - val_loss: 0.1148 - learning_rate: 0.0156
# Epoch 331/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0775 - val_loss: 0.1138 - learning_rate: 0.0156
# Epoch 332/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0844 - val_loss: 0.1141 - learning_rate: 0.0156
# Epoch 333/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0787 - val_loss: 0.1163 - learning_rate: 0.0156
# Epoch 334/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0799 - val_loss: 0.1151 - learning_rate: 0.0156
# Epoch 335/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0855 - val_loss: 0.1144 - learning_rate: 0.0156
# Epoch 336/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0808
# Epoch 336: ReduceLROnPlateau reducing learning rate to 0.0078125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0790 - val_loss: 0.1149 - learning_rate: 0.0156
# Epoch 337/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0870 - val_loss: 0.1149 - learning_rate: 0.0078
# Epoch 338/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0828 - val_loss: 0.1145 - learning_rate: 0.0078
# Epoch 339/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0878 - val_loss: 0.1144 - learning_rate: 0.0078
# Epoch 340/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0820 - val_loss: 0.1144 - learning_rate: 0.0078
# Epoch 341/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0875 - val_loss: 0.1139 - learning_rate: 0.0078
# Epoch 342/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0810 - val_loss: 0.1135 - learning_rate: 0.0078
# Epoch 343/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0794 - val_loss: 0.1139 - learning_rate: 0.0078
# Epoch 344/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0825 - val_loss: 0.1137 - learning_rate: 0.0078
# Epoch 345/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0787 - val_loss: 0.1133 - learning_rate: 0.0078
# Epoch 346/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0926 - val_loss: 0.1133 - learning_rate: 0.0078
# Epoch 347/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0889 - val_loss: 0.1130 - learning_rate: 0.0078
# Epoch 348/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0836 - val_loss: 0.1135 - learning_rate: 0.0078
# Epoch 349/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0875 - val_loss: 0.1127 - learning_rate: 0.0078
# Epoch 350/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0903 - val_loss: 0.1134 - learning_rate: 0.0078
# Epoch 351/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0924 - val_loss: 0.1132 - learning_rate: 0.0078
# Epoch 352/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0827 - val_loss: 0.1134 - learning_rate: 0.0078
# Epoch 353/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0813 - val_loss: 0.1133 - learning_rate: 0.0078
# Epoch 354/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0919 - val_loss: 0.1130 - learning_rate: 0.0078
# Epoch 355/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0784 - val_loss: 0.1129 - learning_rate: 0.0078
# Epoch 356/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0876 - val_loss: 0.1137 - learning_rate: 0.0078
# Epoch 357/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1040 - val_loss: 0.1136 - learning_rate: 0.0078
# Epoch 358/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0922 - val_loss: 0.1125 - learning_rate: 0.0078
# Epoch 359/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0904 - val_loss: 0.1125 - learning_rate: 0.0078
# Epoch 360/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0853 - val_loss: 0.1123 - learning_rate: 0.0078
# Epoch 361/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0845 - val_loss: 0.1123 - learning_rate: 0.0078
# Epoch 362/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0906 - val_loss: 0.1119 - learning_rate: 0.0078
# Epoch 363/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0904 - val_loss: 0.1112 - learning_rate: 0.0078
# Epoch 364/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0888 - val_loss: 0.1110 - learning_rate: 0.0078
# Epoch 365/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0852 - val_loss: 0.1104 - learning_rate: 0.0078
# Epoch 366/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0763 - val_loss: 0.1095 - learning_rate: 0.0078
# Epoch 367/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0829 - val_loss: 0.1100 - learning_rate: 0.0078
# Epoch 368/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0790 - val_loss: 0.1099 - learning_rate: 0.0078
# Epoch 369/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0851 - val_loss: 0.1097 - learning_rate: 0.0078
# Epoch 370/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0784 - val_loss: 0.1098 - learning_rate: 0.0078
# Epoch 371/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0782 - val_loss: 0.1095 - learning_rate: 0.0078
# Epoch 372/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0936 - val_loss: 0.1095 - learning_rate: 0.0078
# Epoch 373/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0989 - val_loss: 0.1098 - learning_rate: 0.0078
# Epoch 374/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0837 - val_loss: 0.1096 - learning_rate: 0.0078
# Epoch 375/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0824 - val_loss: 0.1102 - learning_rate: 0.0078
# Epoch 376/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0597
# Epoch 376: ReduceLROnPlateau reducing learning rate to 0.00390625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0842 - val_loss: 0.1095 - learning_rate: 0.0078
# Epoch 377/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0824 - val_loss: 0.1095 - learning_rate: 0.0039
# Epoch 378/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0852 - val_loss: 0.1092 - learning_rate: 0.0039
# Epoch 379/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0801 - val_loss: 0.1091 - learning_rate: 0.0039
# Epoch 380/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0773 - val_loss: 0.1088 - learning_rate: 0.0039
# Epoch 381/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0872 - val_loss: 0.1089 - learning_rate: 0.0039
# Epoch 382/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0961 - val_loss: 0.1091 - learning_rate: 0.0039
# Epoch 383/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0992 - val_loss: 0.1094 - learning_rate: 0.0039
# Epoch 384/1000
# ...
# Epoch 388/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0813 - val_loss: 0.1089 - learning_rate: 0.0039
# Epoch 389/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0800 - val_loss: 0.1093 - learning_rate: 0.0039
# Epoch 390/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0786 - val_loss: 0.1094 - learning_rate: 0.0039
# Epoch 391/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0924 - val_loss: 0.1091 - learning_rate: 0.0039
# Epoch 392/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1036 - val_loss: 0.1091 - learning_rate: 0.0039
# Epoch 393/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0977 - val_loss: 0.1091 - learning_rate: 0.0039
# Epoch 394/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0971 - val_loss: 0.1089 - learning_rate: 0.0039
# Epoch 395/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0801 - val_loss: 0.1098 - learning_rate: 0.0039
# Epoch 396/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0792
# Epoch 396: ReduceLROnPlateau reducing learning rate to 0.001953125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0867 - val_loss: 0.1102 - learning_rate: 0.0039
# Epoch 397/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0885 - val_loss: 0.1097 - learning_rate: 0.0020
# Epoch 398/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0872 - val_loss: 0.1095 - learning_rate: 0.0020
# Epoch 399/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0881 - val_loss: 0.1094 - learning_rate: 0.0020
# Epoch 400/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0845 - val_loss: 0.1094 - learning_rate: 0.0020
# Epoch 401/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0776 - val_loss: 0.1096 - learning_rate: 0.0020
# Epoch 402/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0799 - val_loss: 0.1098 - learning_rate: 0.0020
# Epoch 403/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0764 - val_loss: 0.1102 - learning_rate: 0.0020
# Epoch 404/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0890 - val_loss: 0.1100 - learning_rate: 0.0020
# Epoch 405/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0802 - val_loss: 0.1101 - learning_rate: 0.0020
# Epoch 406/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1022
# Epoch 406: ReduceLROnPlateau reducing learning rate to 0.0009765625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0953 - val_loss: 0.1104 - learning_rate: 0.0020
# Epoch 407/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0907 - val_loss: 0.1103 - learning_rate: 9.7656e-04
# Epoch 408/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0929 - val_loss: 0.1100 - learning_rate: 9.7656e-04
# Epoch 409/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0838 - val_loss: 0.1099 - learning_rate: 9.7656e-04
# Epoch 410/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0969 - val_loss: 0.1100 - learning_rate: 9.7656e-04
# Epoch 411/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1051 - val_loss: 0.1100 - learning_rate: 9.7656e-04
# Epoch 412/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0863 - val_loss: 0.1100 - learning_rate: 9.7656e-04
# Epoch 413/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0835 - val_loss: 0.1100 - learning_rate: 9.7656e-04
# Epoch 414/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0873 - val_loss: 0.1101 - learning_rate: 9.7656e-04
# Epoch 415/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0951 - val_loss: 0.1099 - learning_rate: 9.7656e-04
# Epoch 416/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0761
# Epoch 416: ReduceLROnPlateau reducing learning rate to 0.00048828125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0837 - val_loss: 0.1098 - learning_rate: 9.7656e-04
# Epoch 417/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0853 - val_loss: 0.1096 - learning_rate: 4.8828e-04
# Epoch 418/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0945 - val_loss: 0.1094 - learning_rate: 4.8828e-04
# Epoch 419/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0760 - val_loss: 0.1094 - learning_rate: 4.8828e-04
# Epoch 420/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0839 - val_loss: 0.1095 - learning_rate: 4.8828e-04
# Epoch 421/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0953 - val_loss: 0.1093 - learning_rate: 4.8828e-04
# Epoch 422/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0791 - val_loss: 0.1094 - learning_rate: 4.8828e-04
# Epoch 423/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0863 - val_loss: 0.1095 - learning_rate: 4.8828e-04
# Epoch 424/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0851 - val_loss: 0.1091 - learning_rate: 4.8828e-04
# Epoch 425/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0980 - val_loss: 0.1089 - learning_rate: 4.8828e-04
# Epoch 426/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0960
# Epoch 426: ReduceLROnPlateau reducing learning rate to 0.000244140625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0902 - val_loss: 0.1090 - learning_rate: 4.8828e-04
# Epoch 427/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1021 - val_loss: 0.1084 - learning_rate: 2.4414e-04
# Epoch 428/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1022 - val_loss: 0.1083 - learning_rate: 2.4414e-04
# Epoch 429/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0833 - val_loss: 0.1080 - learning_rate: 2.4414e-04
# Epoch 430/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0798 - val_loss: 0.1082 - learning_rate: 2.4414e-04
# Epoch 431/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0924 - val_loss: 0.1082 - learning_rate: 2.4414e-04
# Epoch 432/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0973 - val_loss: 0.1082 - learning_rate: 2.4414e-04
# Epoch 433/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0901 - val_loss: 0.1083 - learning_rate: 2.4414e-04
# Epoch 434/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0821 - val_loss: 0.1086 - learning_rate: 2.4414e-04
# Epoch 435/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0890 - val_loss: 0.1088 - learning_rate: 2.4414e-04
# Epoch 436/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0859 - val_loss: 0.1089 - learning_rate: 2.4414e-04
# Epoch 437/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0920 - val_loss: 0.1088 - learning_rate: 2.4414e-04
# Epoch 438/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0852 - val_loss: 0.1088 - learning_rate: 2.4414e-04
# Epoch 439/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0817
# Epoch 439: ReduceLROnPlateau reducing learning rate to 0.0001220703125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0818 - val_loss: 0.1089 - learning_rate: 2.4414e-04
# Epoch 440/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0831 - val_loss: 0.1089 - learning_rate: 1.2207e-04
# Epoch 441/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0883 - val_loss: 0.1088 - learning_rate: 1.2207e-04
# Epoch 442/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0942 - val_loss: 0.1086 - learning_rate: 1.2207e-04
# Epoch 443/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0892 - val_loss: 0.1084 - learning_rate: 1.2207e-04
# Epoch 444/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0869 - val_loss: 0.1084 - learning_rate: 1.2207e-04
# Epoch 445/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0942 - val_loss: 0.1082 - learning_rate: 1.2207e-04
# Epoch 446/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0939 - val_loss: 0.1081 - learning_rate: 1.2207e-04
# Epoch 447/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0869 - val_loss: 0.1077 - learning_rate: 1.2207e-04
# Epoch 448/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0880 - val_loss: 0.1077 - learning_rate: 1.2207e-04
# Epoch 449/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0892 - val_loss: 0.1077 - learning_rate: 1.2207e-04
# Epoch 450/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0846 - val_loss: 0.1079 - learning_rate: 1.2207e-04
# Epoch 451/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0890 - val_loss: 0.1078 - learning_rate: 1.2207e-04
# Epoch 452/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0762 - val_loss: 0.1080 - learning_rate: 1.2207e-04
# Epoch 453/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0755 - val_loss: 0.1082 - learning_rate: 1.2207e-04
# Epoch 454/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0903 - val_loss: 0.1082 - learning_rate: 1.2207e-04
# Epoch 455/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1009 - val_loss: 0.1081 - learning_rate: 1.2207e-04
# Epoch 456/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0869 - val_loss: 0.1081 - learning_rate: 1.2207e-04
# Epoch 457/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0821
# Epoch 457: ReduceLROnPlateau reducing learning rate to 6.103515625e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0860 - val_loss: 0.1081 - learning_rate: 1.2207e-04
# Epoch 458/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0975 - val_loss: 0.1078 - learning_rate: 6.1035e-05
# Epoch 459/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0804 - val_loss: 0.1079 - learning_rate: 6.1035e-05
# Epoch 460/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0884 - val_loss: 0.1076 - learning_rate: 6.1035e-05
# Epoch 461/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0829 - val_loss: 0.1076 - learning_rate: 6.1035e-05
# Epoch 462/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0959 - val_loss: 0.1071 - learning_rate: 6.1035e-05
# Epoch 463/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0843 - val_loss: 0.1071 - learning_rate: 6.1035e-05
# Epoch 464/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0891 - val_loss: 0.1072 - learning_rate: 6.1035e-05
# Epoch 465/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0834 - val_loss: 0.1076 - learning_rate: 6.1035e-05
# Epoch 466/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0966 - val_loss: 0.1077 - learning_rate: 6.1035e-05
# Epoch 467/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0932 - val_loss: 0.1077 - learning_rate: 6.1035e-05
# Epoch 468/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0956 - val_loss: 0.1078 - learning_rate: 6.1035e-05
# Epoch 469/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0791 - val_loss: 0.1079 - learning_rate: 6.1035e-05
# Epoch 470/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0764 - val_loss: 0.1078 - learning_rate: 6.1035e-05
# Epoch 471/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0851 - val_loss: 0.1078 - learning_rate: 6.1035e-05
# Epoch 472/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0896
# Epoch 472: ReduceLROnPlateau reducing learning rate to 3.0517578125e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0829 - val_loss: 0.1077 - learning_rate: 6.1035e-05
# Epoch 473/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0772 - val_loss: 0.1076 - learning_rate: 3.0518e-05
# Epoch 474/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0875 - val_loss: 0.1077 - learning_rate: 3.0518e-05
# Epoch 475/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0799 - val_loss: 0.1078 - learning_rate: 3.0518e-05
# Epoch 476/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0855 - val_loss: 0.1076 - learning_rate: 3.0518e-05
# Epoch 477/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0906 - val_loss: 0.1077 - learning_rate: 3.0518e-05
# Epoch 478/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0868 - val_loss: 0.1076 - learning_rate: 3.0518e-05
# Epoch 479/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0795 - val_loss: 0.1077 - learning_rate: 3.0518e-05
# Epoch 480/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0806 - val_loss: 0.1080 - learning_rate: 3.0518e-05
# Epoch 481/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0890 - val_loss: 0.1079 - learning_rate: 3.0518e-05
# Epoch 482/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0801
# Epoch 482: ReduceLROnPlateau reducing learning rate to 1.52587890625e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0767 - val_loss: 0.1080 - learning_rate: 3.0518e-05
# Epoch 483/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0820 - val_loss: 0.1081 - learning_rate: 1.5259e-05
# Epoch 484/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0779 - val_loss: 0.1083 - learning_rate: 1.5259e-05
# Epoch 485/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0867 - val_loss: 0.1083 - learning_rate: 1.5259e-05
# Epoch 486/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0851 - val_loss: 0.1081 - learning_rate: 1.5259e-05
# Epoch 487/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0890 - val_loss: 0.1080 - learning_rate: 1.5259e-05
# Epoch 488/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0871 - val_loss: 0.1080 - learning_rate: 1.5259e-05
# Epoch 489/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0985 - val_loss: 0.1078 - learning_rate: 1.5259e-05
# Epoch 490/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0960 - val_loss: 0.1079 - learning_rate: 1.5259e-05
# Epoch 491/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0834 - val_loss: 0.1078 - learning_rate: 1.5259e-05
# Epoch 492/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0793
# Epoch 492: ReduceLROnPlateau reducing learning rate to 7.62939453125e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0828 - val_loss: 0.1077 - learning_rate: 1.5259e-05
# Epoch 493/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0867 - val_loss: 0.1077 - learning_rate: 7.6294e-06
# Epoch 494/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0923 - val_loss: 0.1078 - learning_rate: 7.6294e-06
# Epoch 495/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0986 - val_loss: 0.1077 - learning_rate: 7.6294e-06
# Epoch 496/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0767 - val_loss: 0.1077 - learning_rate: 7.6294e-06
# Epoch 497/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0880 - val_loss: 0.1077 - learning_rate: 7.6294e-06
# Epoch 498/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0842 - val_loss: 0.1077 - learning_rate: 7.6294e-06
# Epoch 499/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0841 - val_loss: 0.1077 - learning_rate: 7.6294e-06
# Epoch 500/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0990 - val_loss: 0.1072 - learning_rate: 7.6294e-06
# Epoch 501/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0873 - val_loss: 0.1072 - learning_rate: 7.6294e-06
# Epoch 502/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0981
# Epoch 502: ReduceLROnPlateau reducing learning rate to 3.814697265625e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0848 - val_loss: 0.1073 - learning_rate: 7.6294e-06
# Epoch 503/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0875 - val_loss: 0.1074 - learning_rate: 3.8147e-06
# Epoch 504/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0883 - val_loss: 0.1072 - learning_rate: 3.8147e-06
# Epoch 505/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0793 - val_loss: 0.1072 - learning_rate: 3.8147e-06
# Epoch 506/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0900 - val_loss: 0.1074 - learning_rate: 3.8147e-06
# Epoch 507/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0830 - val_loss: 0.1073 - learning_rate: 3.8147e-06
# Epoch 508/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0828 - val_loss: 0.1074 - learning_rate: 3.8147e-06
# Epoch 509/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0807 - val_loss: 0.1079 - learning_rate: 3.8147e-06
# Epoch 510/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0773 - val_loss: 0.1081 - learning_rate: 3.8147e-06
# Epoch 511/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0803 - val_loss: 0.1080 - learning_rate: 3.8147e-06
# Epoch 512/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0835
# Epoch 512: ReduceLROnPlateau reducing learning rate to 1.9073486328125e-06.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0859 - val_loss: 0.1081 - learning_rate: 3.8147e-06
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# Training R2 Score: 0.9304534928144613
# Testing R2 Score: 0.7799311157183224
# Training Mean Absolute Error: 0.039518695070835656
# Testing Mean Absolute Error: 0.08400388527802065
