# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn import preprocessing
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta, Adamax, Nadam
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, r2_score,mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2024-10-06 13:40:21.801716: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dataset = pd.read_csv("data_for_traing_ml_models.csv")

#####################

'''
7-feature dataset is run on Simple Linear Regression, LASSO, Ridge, Random Forest and Neural Network models for the prediction of Energy above convex hull of MXenes.
'''
# Out:
# '\n7-feature dataset is run on Simple Linear Regression, LASSO, Ridge, Random Forest and Neural Network models for the prediction of Energy above convex hull of MXenes.\n'

# %%
# take a look at the dataset
dataset.head()
dataset.describe()
# Out:
#        Work_function  Heat_of_formation  Energy_above_convex_hull   Length(x)  \
# count     275.000000         275.000000                275.000000  275.000000
# mean        4.264700          -1.062837                  0.315639  311.577091
# std         1.530484           0.835387                  0.228956   20.841980
# min         1.347678          -2.984132                  0.000000  262.100000
# 25%         2.792242          -1.646810                  0.162571  294.700000
# 50%         4.537063          -1.079087                  0.268825  312.500000
# 75%         5.349280          -0.483631                  0.424251  324.000000
# max         7.271891           0.957153                  1.138551  378.300000
#
#        Radius_of_orbital_of_metal  Radius_of_orbital_of_support  \
# count                  275.000000                    275.000000
# mean                    65.518545                     54.219636
# std                     16.428133                      5.409809
# min                     38.900000                     48.800000
# 25%                     48.900000                     48.800000
# 50%                     74.600000                     59.600000
# 75%                     79.000000                     59.600000
# max                     86.500000                     59.600000
#
#        Radius_of_orbital_of_termination  Ionisation_potential_of_metal  \
# count                        275.000000                     275.000000
# mean                          45.983636                       6.980777
# std                           13.987596                       0.518915
# min                           36.000000                       6.217000
# 25%                           38.900000                       6.633900
# 50%                           41.400000                       6.825000
# 75%                           41.400000                       7.264100
# max                           86.500000                       7.980000
#
#        Ionisation_potential_of_support  Ionisation_potential_of_termination  \
# count                       275.000000                           275.000000
# mean                         12.891248                            12.719608
# std                           1.639873                             3.765861
# min                          11.260300                             6.217000
# 25%                          11.260300                             7.980000
# 50%                          11.260300                            13.017000
# 75%                          14.534100                            13.618000
# max                          14.534100                            17.422800
#
#        Electronegativity_of_metal  Electronegativity_of_support  \
# count                  275.000000                    275.000000
# mean                     1.601527                      2.794109
# std                      0.333816                      0.245445
# min                      1.220000                      2.550000
# 25%                      1.330000                      2.550000
# 50%                      1.540000                      2.550000
# 75%                      1.630000                      3.040000
# max                      2.360000                      3.040000
#
#        Electronegativity_of_termination  Electron_affinity_of_metal  \
# count                        275.000000                  275.000000
# mean                           2.951018                    0.394964
# std                            0.903641                    0.364981
# min                            1.220000                   -0.500000
# 25%                            2.360000                    0.189000
# 50%                            2.820000                    0.323000
# 75%                            3.440000                    0.749000
# max                            3.980000                    0.894000
#
#        Electron_affinity_of_support  Electron_affinity_of_termination
# count                    275.000000                        275.000000
# mean                       0.598422                          1.755294
# std                        0.667210                          1.099077
# min                       -0.070000                         -0.500000
# 25%                       -0.070000                          0.894000
# 50%                        1.262000                          1.439000
# 75%                        1.262000                          1.827000
# max                        1.262000                          3.401000

# %%
cdf = dataset[['Work_function','Heat_of_formation','Energy_above_convex_hull','Length(x)','Radius_of_orbital_of_metal','Radius_of_orbital_of_support','Radius_of_orbital_of_termination','Ionisation_potential_of_metal','Ionisation_potential_of_support','Ionisation_potential_of_termination','Electronegativity_of_metal','Electronegativity_of_support','Electronegativity_of_termination','Electron_affinity_of_metal','Electron_affinity_of_support','Electron_affinity_of_termination']]
cdf.head(9)
# Out:
#    Work_function  Heat_of_formation  Energy_above_convex_hull  Length(x)  \
# 0       2.271378          -1.345952                  0.242880      330.4
# 1       1.588009          -1.199954                  0.452744      335.0
# 2       2.209840          -0.317344                  0.473693      290.6
# 3       2.463148          -0.594739                  0.327053      285.0
# 4       2.329750          -1.597694                  0.163033      298.9
# 5       2.429486          -1.645322                  0.315790      320.4
# 6       6.244289          -0.755420                  0.290092      293.1
# 7       4.424606          -1.265524                  0.269073      316.7
# 8       4.468438          -1.715968                  0.168985      348.9
#
#    Radius_of_orbital_of_metal  Radius_of_orbital_of_support  \
# 0                        82.9                          59.6
# 1                        53.9                          59.6
# 2                        74.6                          59.6
# 3                        70.2                          48.8
# 4                        48.9                          48.8
# 5                        79.0                          48.8
# 6                        38.9                          59.6
# 7                        78.4                          59.6
# 8                        86.5                          59.6
#
#    Radius_of_orbital_of_termination  Ionisation_potential_of_metal  \
# 0                              41.4                         6.8250
# 1                              41.4                         6.5614
# 2                              41.4                         7.9800
# 3                              41.4                         7.0942
# 4                              41.4                         6.8282
# 5                              41.4                         6.6339
# 6                              36.0                         7.4340
# 7                              36.0                         7.8900
# 8                              36.0                         6.2170
#
#    Ionisation_potential_of_support  Ionisation_potential_of_termination  \
# 0                          11.2603                              13.0170
# 1                          11.2603                              13.0170
# 2                          11.2603                              13.0170
# 3                          14.5341                              13.0170
# 4                          14.5341                              13.0170
# 5                          14.5341                              13.0170
# 6                          11.2603                              17.4228
# 7                          11.2603                              17.4228
# 8                          11.2603                              17.4228
#
#    Electronegativity_of_metal  Electronegativity_of_support  \
# 0                        1.30                          2.55
# 1                        1.36                          2.55
# 2                        2.36                          2.55
# 3                        2.16                          3.04
# 4                        1.54                          3.04
# 5                        1.33                          3.04
# 6                        1.55                          2.55
# 7                        1.50                          2.55
# 8                        1.22                          2.55
#
#    Electronegativity_of_termination  Electron_affinity_of_metal  \
# 0                              2.82                       0.178
# 1                              2.82                       0.189
# 2                              2.82                       0.816
# 3                              2.82                       0.749
# 4                              2.82                       0.087
# 5                              2.82                       0.427
# 6                              3.98                      -0.500
# 7                              3.98                       0.323
# 8                              3.98                       0.308
#
#    Electron_affinity_of_support  Electron_affinity_of_termination
# 0                         1.262                             1.827
# 1                         1.262                             1.827
# 2                         1.262                             1.827
# 3                        -0.070                             1.827
# 4                        -0.070                             1.827
# 5                        -0.070                             1.827
# 6                         1.262                             3.401
# 7                         1.262                             3.401
# 8                         1.262                             3.401

# %%
###################### Simple Linear Regression

regr = LinearRegression()

# Assuming 'HoF', 'E_Hull', 'Length(x)', ..., are your features
features = ['Radius_of_orbital_of_metal','Radius_of_orbital_of_termination', 'Ionisation_potential_of_metal','Ionisation_potential_of_support','Electronegativity_of_metal','Electronegativity_of_termination','Electron_affinity_of_metal']
target = ['Energy_above_convex_hull']

# Split the data into train and test sets
train, test = train_test_split(dataset, test_size=0.2, random_state=42)

# Train set
train_x = np.asanyarray(train[features])
train_y = np.asanyarray(train[target])

# Test set
test_x = np.asanyarray(test[features])
test_y = np.asanyarray(test[target])

# Create and train the Linear Regression model
regr.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat = regr.predict(train_x)
test_y_hat = regr.predict(test_x)

# Calculate MSE, MAE, and R2 for the train set
train_mse = mean_squared_error(train_y, train_y_hat)
train_mae = mean_absolute_error(train_y, train_y_hat)
train_r2 = r2_score(train_y, train_y_hat)

# Calculate MSE, MAE, and R2 for the test set
test_mse = mean_squared_error(test_y, test_y_hat)
test_mae = mean_absolute_error(test_y, test_y_hat)
test_r2 = r2_score(test_y, test_y_hat)

# Print the results
print('Linear Regression\n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse)
print("MAE: %.2f" % train_mae)
print("R2 Score: %.2f" % train_r2)
print('LinearRegression\n')
print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse)
print("MAE: %.2f" % test_mae)
print("R2 Score: %.2f" % test_r2)
# Out:
# Linear Regression
#
# Train set metrics:
# MAE: 0.12
# R2 Score: 0.46
# LinearRegression
#
#
# Test set metrics:
# MAE: 0.14
# R2 Score: 0.43

# %%
####################### LASSO Regression


# Initialize LASSO model
regr1 = Lasso()
# Create and train the LASSO Regression model
regr1.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat1 = regr1.predict(train_x)
test_y_hat1 = regr1.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse1 = mean_squared_error(train_y, train_y_hat1)
train_mae1 = mean_absolute_error(train_y, train_y_hat1)
train_r2_1 = r2_score(train_y, train_y_hat1)

# Calculate MSE, MAE, and R2 for the test set
test_mse1 = mean_squared_error(test_y, test_y_hat1)
test_mae1 = mean_absolute_error(test_y, test_y_hat1)
test_r2_1 = r2_score(test_y, test_y_hat1)

# Print the results
print('LASSO Regression')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse1)
print("MAE: %.2f" % train_mae1)
print("R2 Score: %.2f" % train_r2_1)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse1)
print("MAE: %.2f" % test_mae1)
print("R2 Score: %.2f" % test_r2_1)
# Out:
# LASSO Regression
# Train set metrics:
# MAE: 0.16
# R2 Score: 0.14
#
# Test set metrics:
# MAE: 0.18
# R2 Score: 0.12

# %%
####################### Ridge Regression



# Initialize Ridge Regression
regr2 = Ridge()
# Create and train the Ridge Regression model
regr2.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat2 = regr2.predict(train_x)
test_y_hat2 = regr2.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse2 = mean_squared_error(train_y, train_y_hat2)
train_mae2 = mean_absolute_error(train_y, train_y_hat2)
train_r2_2 = r2_score(train_y, train_y_hat2)

# Calculate MSE, MAE, and R2 for the test set
test_mse2 = mean_squared_error(test_y, test_y_hat2)
test_mae2 = mean_absolute_error(test_y, test_y_hat2)
test_r2_2 = r2_score(test_y, test_y_hat2)

# Print the results
print('Ridge Regression\n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse2)
print("MAE: %.2f" % train_mae2)
print("R2 Score: %.2f" % train_r2_2)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse2)
print("MAE: %.2f" % test_mae2)
print("R2 Score: %.2f" % test_r2_2)
# Out:
# Ridge Regression
#
# Train set metrics:
# MAE: 0.12
# R2 Score: 0.45
#
# Test set metrics:
# MAE: 0.14
# R2 Score: 0.43

# %%
###################### Random Forest Regression



# Initialize Random Forest Regression
regr3 = RandomForestRegressor()
# Create and train the Random Forest Regression model
regr3.fit(train_x, train_y)

# Predictions on train and test sets
train_y_hat3 = regr3.predict(train_x)
test_y_hat3 = regr3.predict(test_x)


# Calculate MSE, MAE, and R2 for the train set
train_mse3 = mean_squared_error(train_y, train_y_hat3)
train_mae3 = mean_absolute_error(train_y, train_y_hat3)
train_r2_3 = r2_score(train_y, train_y_hat3)

# Calculate MSE, MAE, and R2 for the test set
test_mse3 = mean_squared_error(test_y, test_y_hat3)
test_mae3 = mean_absolute_error(test_y, test_y_hat3)
test_r2_3 = r2_score(test_y, test_y_hat3)

# Print the results
print('Random Forest Regression \n')
print("Train set metrics:")
#print("MSE: %.2f" % train_mse3)
print("MAE: %.2f" % train_mae3)
print("R2 Score: %.2f" % train_r2_3)

print("\nTest set metrics:")
#print("MSE: %.2f" % test_mse3)
print("MAE: %.2f" % test_mae3)
print("R2 Score: %.2f" % test_r2_3)
# Out:
# /home/azaan/anaconda3/envs/data_science/lib/python3.9/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest Regression
#
# Train set metrics:
# MAE: 0.06
# R2 Score: 0.83
#
# Test set metrics:
# MAE: 0.12
# R2 Score: 0.55

# %% [markdown]
# ################## Neural Network Regression

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam, RMSprop, Nadam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Preprocessing
dataset_columns = dataset.columns
columns_to_exclude = ['Formula', 'M', 'X', 'T', 'Work_function', 'Heat_of_formation', 'Energy_above_convex_hull', 'Length(x)','Radius_of_orbital_of_support','Electron_affinity_of_termination','Electronegativity_of_support','Ionisation_potential_of_termination','Electron_affinity_of_support']
predictors = dataset.drop(columns=columns_to_exclude)
target = dataset['Energy_above_convex_hull']
predictors_norm = (predictors - predictors.mean()) / predictors.std()

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.2, random_state=42)

# Get the number of input features
n_cols = predictors_norm.shape[1]

def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(1024, activation='relu', input_shape=(n_cols,), kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    model.add(Dense(512, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Dense(256, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Dense(128, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Dense(64, activation='relu', kernel_regularizer='l2'))
    model.add(BatchNormalization())
    
    model.add(Dense(1))

    # optimizer setup
    optimizer = Adadelta(learning_rate=1.0)
    
    model.compile(optimizer=optimizer, loss='mae')
    return model

# Build the model
model = regression_model()

# Early stopping and learning rate reduction callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1)

# Fit the model
history = model.fit(X_train, y_train, 
                    batch_size=32, 
                    validation_split=0.2, 
                    epochs=1000, 
                    verbose=1, 
                    callbacks=[early_stopping, reduce_lr])

# Make predictions on the training set
train_predictions = model.predict(X_train)

# Make predictions on the testing set
test_predictions = model.predict(X_test)

# Calculate R2 score for training and testing sets
r2_train = r2_score(y_train, train_predictions)
r2_test = r2_score(y_test, test_predictions)

# Calculate MAE for training and testing sets
mae_train = mean_absolute_error(y_train, train_predictions)
mae_test = mean_absolute_error(y_test, test_predictions)

# Print the results
print(f'Training R2 Score: {r2_train}')
print(f'Testing R2 Score: {r2_test}')
print(f'Training Mean Absolute Error: {mae_train}')
print(f'Testing Mean Absolute Error: {mae_test}')
# Out:
# /home/azaan/anaconda3/envs/data_science/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-10-06 13:40:24.907467: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:40:24.920701: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:40:24.921118: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:40:24.923445: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:40:24.923808: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:40:24.924077: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:40:24.986002: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:40:24.986277: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:40:24.986527: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-06 13:40:24.986655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 212 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 960M, pci bus id: 0000:01:00.0, compute capability: 5.0
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728204029.572909  299651 service.cc:145] XLA service 0x7493640077d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728204029.572937  299651 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 960M, Compute Capability 5.0
# 2024-10-06 13:40:29.688893: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-06 13:40:30.217600: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 1:10 14s/step - loss: 14.0241
# I0000 00:00:1728204039.501655  299651 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - loss: 14.0430 - val_loss: 13.0615 - learning_rate: 1.0000
# Epoch 2/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 13.7788 - val_loss: 12.8809 - learning_rate: 1.0000
# Epoch 3/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.4727 - val_loss: 12.7163 - learning_rate: 1.0000
# Epoch 4/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.2091 - val_loss: 12.5282 - learning_rate: 1.0000
# Epoch 5/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.9231 - val_loss: 12.3387 - learning_rate: 1.0000
# Epoch 6/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.7155 - val_loss: 12.1501 - learning_rate: 1.0000
# Epoch 7/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.4798 - val_loss: 11.9405 - learning_rate: 1.0000
# Epoch 8/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.2620 - val_loss: 11.7604 - learning_rate: 1.0000
# Epoch 9/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 12.0321 - val_loss: 11.5548 - learning_rate: 1.0000
# Epoch 10/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.8115 - val_loss: 11.3766 - learning_rate: 1.0000
# Epoch 11/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.5817 - val_loss: 11.1763 - learning_rate: 1.0000
# Epoch 12/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.3703 - val_loss: 10.9951 - learning_rate: 1.0000
# Epoch 13/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.1622 - val_loss: 10.7735 - learning_rate: 1.0000
# Epoch 14/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.9342 - val_loss: 10.5699 - learning_rate: 1.0000
# Epoch 15/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.7078 - val_loss: 10.3656 - learning_rate: 1.0000
# Epoch 16/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.4528 - val_loss: 10.1497 - learning_rate: 1.0000
# Epoch 17/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.3100 - val_loss: 9.9439 - learning_rate: 1.0000
# Epoch 18/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.0402 - val_loss: 9.7337 - learning_rate: 1.0000
# Epoch 19/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.8513 - val_loss: 9.5213 - learning_rate: 1.0000
# Epoch 20/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.5968 - val_loss: 9.2788 - learning_rate: 1.0000
# Epoch 21/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.3511 - val_loss: 9.0700 - learning_rate: 1.0000
# Epoch 22/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.1381 - val_loss: 8.8266 - learning_rate: 1.0000
# Epoch 23/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8657 - val_loss: 8.5937 - learning_rate: 1.0000
# Epoch 24/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.6152 - val_loss: 8.3724 - learning_rate: 1.0000
# Epoch 25/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.4393 - val_loss: 8.1331 - learning_rate: 1.0000
# Epoch 26/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.1372 - val_loss: 7.8969 - learning_rate: 1.0000
# Epoch 27/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.9706 - val_loss: 7.6675 - learning_rate: 1.0000
# Epoch 28/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.6634 - val_loss: 7.4562 - learning_rate: 1.0000
# Epoch 29/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.4630 - val_loss: 7.2057 - learning_rate: 1.0000
# Epoch 30/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.2591 - val_loss: 6.9710 - learning_rate: 1.0000
# Epoch 31/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.9894 - val_loss: 6.7388 - learning_rate: 1.0000
# Epoch 32/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.7245 - val_loss: 6.5131 - learning_rate: 1.0000
# Epoch 33/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.5094 - val_loss: 6.2968 - learning_rate: 1.0000
# Epoch 34/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.3273 - val_loss: 6.0822 - learning_rate: 1.0000
# Epoch 35/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.0846 - val_loss: 5.8655 - learning_rate: 1.0000
# Epoch 36/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8808 - val_loss: 5.6540 - learning_rate: 1.0000
# Epoch 37/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6783 - val_loss: 5.4874 - learning_rate: 1.0000
# Epoch 38/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4645 - val_loss: 5.2728 - learning_rate: 1.0000
# Epoch 39/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2570 - val_loss: 5.0654 - learning_rate: 1.0000
# Epoch 40/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1110 - val_loss: 4.8835 - learning_rate: 1.0000
# Epoch 41/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8864 - val_loss: 4.7119 - learning_rate: 1.0000
# Epoch 42/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7174 - val_loss: 4.5239 - learning_rate: 1.0000
# Epoch 43/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5155 - val_loss: 4.3579 - learning_rate: 1.0000
# Epoch 44/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3528 - val_loss: 4.2067 - learning_rate: 1.0000
# Epoch 45/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2253 - val_loss: 4.0498 - learning_rate: 1.0000
# Epoch 46/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0329 - val_loss: 3.8944 - learning_rate: 1.0000
# Epoch 47/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8768 - val_loss: 3.7486 - learning_rate: 1.0000
# Epoch 48/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.7305 - val_loss: 3.6040 - learning_rate: 1.0000
# Epoch 49/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5924 - val_loss: 3.4687 - learning_rate: 1.0000
# Epoch 50/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4593 - val_loss: 3.3352 - learning_rate: 1.0000
# Epoch 51/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2965 - val_loss: 3.2065 - learning_rate: 1.0000
# Epoch 52/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1967 - val_loss: 3.0925 - learning_rate: 1.0000
# Epoch 53/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0973 - val_loss: 2.9802 - learning_rate: 1.0000
# Epoch 54/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9632 - val_loss: 2.8595 - learning_rate: 1.0000
# Epoch 55/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8485 - val_loss: 2.7487 - learning_rate: 1.0000
# Epoch 56/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7371 - val_loss: 2.6521 - learning_rate: 1.0000
# Epoch 57/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6377 - val_loss: 2.5629 - learning_rate: 1.0000
# Epoch 58/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5358 - val_loss: 2.4624 - learning_rate: 1.0000
# Epoch 59/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4415 - val_loss: 2.3695 - learning_rate: 1.0000
# Epoch 60/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3464 - val_loss: 2.3074 - learning_rate: 1.0000
# Epoch 61/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2655 - val_loss: 2.1993 - learning_rate: 1.0000
# Epoch 62/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1765 - val_loss: 2.1170 - learning_rate: 1.0000
# Epoch 63/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0788 - val_loss: 2.0370 - learning_rate: 1.0000
# Epoch 64/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9992 - val_loss: 1.9733 - learning_rate: 1.0000
# Epoch 65/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9504 - val_loss: 1.8944 - learning_rate: 1.0000
# Epoch 66/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8546 - val_loss: 1.8300 - learning_rate: 1.0000
# Epoch 67/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7742 - val_loss: 1.7713 - learning_rate: 1.0000
# Epoch 68/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7067 - val_loss: 1.6931 - learning_rate: 1.0000
# Epoch 69/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6399 - val_loss: 1.6393 - learning_rate: 1.0000
# Epoch 70/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5971 - val_loss: 1.6083 - learning_rate: 1.0000
# Epoch 71/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5412 - val_loss: 1.5405 - learning_rate: 1.0000
# Epoch 72/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5116 - val_loss: 1.5339 - learning_rate: 1.0000
# Epoch 73/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4260 - val_loss: 1.4579 - learning_rate: 1.0000
# Epoch 74/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4007 - val_loss: 1.3930 - learning_rate: 1.0000
# Epoch 75/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3460 - val_loss: 1.3392 - learning_rate: 1.0000
# Epoch 76/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3075 - val_loss: 1.2917 - learning_rate: 1.0000
# Epoch 77/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2535 - val_loss: 1.2508 - learning_rate: 1.0000
# Epoch 78/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2107 - val_loss: 1.2169 - learning_rate: 1.0000
# Epoch 79/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1756 - val_loss: 1.1792 - learning_rate: 1.0000
# Epoch 80/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1387 - val_loss: 1.1585 - learning_rate: 1.0000
# Epoch 81/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1175 - val_loss: 1.1109 - learning_rate: 1.0000
# Epoch 82/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0553 - val_loss: 1.0774 - learning_rate: 1.0000
# Epoch 83/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0484 - val_loss: 1.0412 - learning_rate: 1.0000
# Epoch 84/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0094 - val_loss: 1.0101 - learning_rate: 1.0000
# Epoch 85/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9765 - val_loss: 0.9893 - learning_rate: 1.0000
# Epoch 86/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9479 - val_loss: 0.9586 - learning_rate: 1.0000
# Epoch 87/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9145 - val_loss: 0.9318 - learning_rate: 1.0000
# Epoch 88/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8959 - val_loss: 0.9112 - learning_rate: 1.0000
# Epoch 89/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8703 - val_loss: 0.8864 - learning_rate: 1.0000
# Epoch 90/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8435 - val_loss: 0.8712 - learning_rate: 1.0000
# Epoch 91/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8181 - val_loss: 0.8430 - learning_rate: 1.0000
# Epoch 92/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8010 - val_loss: 0.8384 - learning_rate: 1.0000
# Epoch 93/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7690 - val_loss: 0.7953 - learning_rate: 1.0000
# Epoch 94/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7642 - val_loss: 0.7824 - learning_rate: 1.0000
# Epoch 95/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7496 - val_loss: 0.7572 - learning_rate: 1.0000
# Epoch 96/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7355 - val_loss: 0.7483 - learning_rate: 1.0000
# Epoch 97/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6928 - val_loss: 0.7220 - learning_rate: 1.0000
# Epoch 98/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7007 - val_loss: 0.7064 - learning_rate: 1.0000
# Epoch 99/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6602 - val_loss: 0.6978 - learning_rate: 1.0000
# Epoch 100/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6585 - val_loss: 0.6711 - learning_rate: 1.0000
# Epoch 101/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6586 - val_loss: 0.6575 - learning_rate: 1.0000
# Epoch 102/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6314 - val_loss: 0.6389 - learning_rate: 1.0000
# Epoch 103/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6199 - val_loss: 0.6323 - learning_rate: 1.0000
# Epoch 104/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6013 - val_loss: 0.6203 - learning_rate: 1.0000
# Epoch 105/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5700 - val_loss: 0.6203 - learning_rate: 1.0000
# Epoch 106/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5723 - val_loss: 0.6023 - learning_rate: 1.0000
# Epoch 107/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5701 - val_loss: 0.5853 - learning_rate: 1.0000
# Epoch 108/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5444 - val_loss: 0.5654 - learning_rate: 1.0000
# Epoch 109/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5419 - val_loss: 0.5546 - learning_rate: 1.0000
# Epoch 110/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4995 - val_loss: 0.5368 - learning_rate: 1.0000
# Epoch 111/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4916 - val_loss: 0.5268 - learning_rate: 1.0000
# Epoch 112/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4824 - val_loss: 0.5270 - learning_rate: 1.0000
# Epoch 113/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4906 - val_loss: 0.5064 - learning_rate: 1.0000
# Epoch 114/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4635 - val_loss: 0.5153 - learning_rate: 1.0000
# Epoch 115/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4552 - val_loss: 0.5141 - learning_rate: 1.0000
# Epoch 116/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4611 - val_loss: 0.4931 - learning_rate: 1.0000
# Epoch 117/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4583 - val_loss: 0.4791 - learning_rate: 1.0000
# Epoch 118/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4545 - val_loss: 0.4638 - learning_rate: 1.0000
# Epoch 119/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4365 - val_loss: 0.4537 - learning_rate: 1.0000
# Epoch 120/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4166 - val_loss: 0.4485 - learning_rate: 1.0000
# Epoch 121/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3961 - val_loss: 0.4422 - learning_rate: 1.0000
# Epoch 122/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3882 - val_loss: 0.4249 - learning_rate: 1.0000
# Epoch 123/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3811 - val_loss: 0.4186 - learning_rate: 1.0000
# Epoch 124/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3860 - val_loss: 0.4037 - learning_rate: 1.0000
# Epoch 125/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3807 - val_loss: 0.4265 - learning_rate: 1.0000
# Epoch 126/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3972 - val_loss: 0.4219 - learning_rate: 1.0000
# Epoch 127/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3649 - val_loss: 0.3971 - learning_rate: 1.0000
# Epoch 128/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3636 - val_loss: 0.3935 - learning_rate: 1.0000
# Epoch 129/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3725 - val_loss: 0.3947 - learning_rate: 1.0000
# Epoch 130/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3562 - val_loss: 0.3848 - learning_rate: 1.0000
# Epoch 131/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3508 - val_loss: 0.3658 - learning_rate: 1.0000
# Epoch 132/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3456 - val_loss: 0.3607 - learning_rate: 1.0000
# Epoch 133/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3605 - val_loss: 0.3601 - learning_rate: 1.0000
# Epoch 134/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3217 - val_loss: 0.3496 - learning_rate: 1.0000
# Epoch 135/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3383 - val_loss: 0.3578 - learning_rate: 1.0000
# Epoch 136/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3631 - val_loss: 0.3511 - learning_rate: 1.0000
# Epoch 137/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3134 - val_loss: 0.3453 - learning_rate: 1.0000
# Epoch 138/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3090 - val_loss: 0.3304 - learning_rate: 1.0000
# Epoch 139/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3005 - val_loss: 0.3142 - learning_rate: 1.0000
# Epoch 140/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3039 - val_loss: 0.3088 - learning_rate: 1.0000
# Epoch 141/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3089 - val_loss: 0.3246 - learning_rate: 1.0000
# Epoch 142/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3090 - val_loss: 0.3163 - learning_rate: 1.0000
# Epoch 143/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3051 - val_loss: 0.3127 - learning_rate: 1.0000
# Epoch 144/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2891 - val_loss: 0.3138 - learning_rate: 1.0000
# Epoch 145/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3038 - val_loss: 0.3091 - learning_rate: 1.0000
# Epoch 146/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2863 - val_loss: 0.3067 - learning_rate: 1.0000
# Epoch 147/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2881 - val_loss: 0.3008 - learning_rate: 1.0000
# Epoch 148/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2937 - val_loss: 0.2824 - learning_rate: 1.0000
# Epoch 149/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2727 - val_loss: 0.2884 - learning_rate: 1.0000
# Epoch 150/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2670 - val_loss: 0.2938 - learning_rate: 1.0000
# Epoch 151/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2733 - val_loss: 0.2825 - learning_rate: 1.0000
# Epoch 152/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2610 - val_loss: 0.2831 - learning_rate: 1.0000
# Epoch 153/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2402 - val_loss: 0.2806 - learning_rate: 1.0000
# Epoch 154/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2529 - val_loss: 0.2750 - learning_rate: 1.0000
# Epoch 155/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2553 - val_loss: 0.2689 - learning_rate: 1.0000
# Epoch 156/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2507 - val_loss: 0.2640 - learning_rate: 1.0000
# Epoch 157/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2489 - val_loss: 0.2646 - learning_rate: 1.0000
# Epoch 158/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2394 - val_loss: 0.2740 - learning_rate: 1.0000
# Epoch 159/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2588 - val_loss: 0.2926 - learning_rate: 1.0000
# Epoch 160/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2651 - val_loss: 0.2688 - learning_rate: 1.0000
# Epoch 161/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2650 - val_loss: 0.2537 - learning_rate: 1.0000
# Epoch 162/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2532 - val_loss: 0.2697 - learning_rate: 1.0000
# Epoch 163/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2529 - val_loss: 0.2438 - learning_rate: 1.0000
# Epoch 164/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2388 - val_loss: 0.2464 - learning_rate: 1.0000
# Epoch 165/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2507 - val_loss: 0.2482 - learning_rate: 1.0000
# Epoch 166/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2458 - val_loss: 0.2365 - learning_rate: 1.0000
# Epoch 167/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2106 - val_loss: 0.2395 - learning_rate: 1.0000
# Epoch 168/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2410 - val_loss: 0.2392 - learning_rate: 1.0000
# Epoch 169/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2340 - val_loss: 0.2261 - learning_rate: 1.0000
# Epoch 170/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2242 - val_loss: 0.2211 - learning_rate: 1.0000
# Epoch 171/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2206 - val_loss: 0.2338 - learning_rate: 1.0000
# Epoch 172/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2268 - val_loss: 0.2535 - learning_rate: 1.0000
# Epoch 173/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2214 - val_loss: 0.2305 - learning_rate: 1.0000
# Epoch 174/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2136 - val_loss: 0.2361 - learning_rate: 1.0000
# Epoch 175/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2198 - val_loss: 0.2508 - learning_rate: 1.0000
# Epoch 176/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2201 - val_loss: 0.2116 - learning_rate: 1.0000
# Epoch 177/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2197 - val_loss: 0.2187 - learning_rate: 1.0000
# Epoch 178/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1983 - val_loss: 0.2406 - learning_rate: 1.0000
# Epoch 179/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2079 - val_loss: 0.2262 - learning_rate: 1.0000
# Epoch 180/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2038 - val_loss: 0.2432 - learning_rate: 1.0000
# Epoch 181/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2028 - val_loss: 0.2166 - learning_rate: 1.0000
# Epoch 182/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2047 - val_loss: 0.2149 - learning_rate: 1.0000
# Epoch 183/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1995 - val_loss: 0.2393 - learning_rate: 1.0000
# Epoch 184/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2157 - val_loss: 0.2353 - learning_rate: 1.0000
# Epoch 185/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2072 - val_loss: 0.2211 - learning_rate: 1.0000
# Epoch 186/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1850
# Epoch 186: ReduceLROnPlateau reducing learning rate to 0.5.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1869 - val_loss: 0.2243 - learning_rate: 1.0000
# Epoch 187/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1959 - val_loss: 0.2124 - learning_rate: 0.5000
# Epoch 188/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1736 - val_loss: 0.2100 - learning_rate: 0.5000
# Epoch 189/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1804 - val_loss: 0.2150 - learning_rate: 0.5000
# Epoch 190/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1836 - val_loss: 0.2078 - learning_rate: 0.5000
# Epoch 191/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1787 - val_loss: 0.2043 - learning_rate: 0.5000
# Epoch 192/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1632 - val_loss: 0.2035 - learning_rate: 0.5000
# Epoch 193/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1692 - val_loss: 0.1987 - learning_rate: 0.5000
# Epoch 194/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1665 - val_loss: 0.2045 - learning_rate: 0.5000
# Epoch 195/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1744 - val_loss: 0.2091 - learning_rate: 0.5000
# Epoch 196/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1770 - val_loss: 0.1960 - learning_rate: 0.5000
# Epoch 197/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1726 - val_loss: 0.2048 - learning_rate: 0.5000
# Epoch 198/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1790 - val_loss: 0.1981 - learning_rate: 0.5000
# Epoch 199/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1752 - val_loss: 0.1966 - learning_rate: 0.5000
# Epoch 200/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1739 - val_loss: 0.2193 - learning_rate: 0.5000
# Epoch 201/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1819 - val_loss: 0.2105 - learning_rate: 0.5000
# Epoch 202/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1775 - val_loss: 0.1862 - learning_rate: 0.5000
# Epoch 203/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1672 - val_loss: 0.2080 - learning_rate: 0.5000
# Epoch 204/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1627 - val_loss: 0.1811 - learning_rate: 0.5000
# Epoch 205/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1561 - val_loss: 0.1886 - learning_rate: 0.5000
# Epoch 206/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1660 - val_loss: 0.1848 - learning_rate: 0.5000
# Epoch 207/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1653 - val_loss: 0.1848 - learning_rate: 0.5000
# Epoch 208/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1569 - val_loss: 0.1695 - learning_rate: 0.5000
# Epoch 209/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1697 - val_loss: 0.1903 - learning_rate: 0.5000
# Epoch 210/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1629 - val_loss: 0.1729 - learning_rate: 0.5000
# Epoch 211/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1633 - val_loss: 0.1804 - learning_rate: 0.5000
# Epoch 212/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1571 - val_loss: 0.1746 - learning_rate: 0.5000
# Epoch 213/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1565 - val_loss: 0.1700 - learning_rate: 0.5000
# Epoch 214/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1625 - val_loss: 0.1854 - learning_rate: 0.5000
# Epoch 215/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1560 - val_loss: 0.1884 - learning_rate: 0.5000
# Epoch 216/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1650 - val_loss: 0.1706 - learning_rate: 0.5000
# Epoch 217/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1574 - val_loss: 0.1708 - learning_rate: 0.5000
# Epoch 218/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1434
# Epoch 218: ReduceLROnPlateau reducing learning rate to 0.25.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1462 - val_loss: 0.1793 - learning_rate: 0.5000
# Epoch 219/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1521 - val_loss: 0.1816 - learning_rate: 0.2500
# Epoch 220/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1458 - val_loss: 0.1904 - learning_rate: 0.2500
# Epoch 221/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1428 - val_loss: 0.1831 - learning_rate: 0.2500
# Epoch 222/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1535 - val_loss: 0.1928 - learning_rate: 0.2500
# Epoch 223/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1514 - val_loss: 0.1872 - learning_rate: 0.2500
# Epoch 224/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1520 - val_loss: 0.1793 - learning_rate: 0.2500
# Epoch 225/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1458 - val_loss: 0.1774 - learning_rate: 0.2500
# Epoch 226/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1316 - val_loss: 0.1720 - learning_rate: 0.2500
# Epoch 227/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1429 - val_loss: 0.1734 - learning_rate: 0.2500
# Epoch 228/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1336
# Epoch 228: ReduceLROnPlateau reducing learning rate to 0.125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1405 - val_loss: 0.1775 - learning_rate: 0.2500
# Epoch 229/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1404 - val_loss: 0.1695 - learning_rate: 0.1250
# Epoch 230/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1201 - val_loss: 0.1723 - learning_rate: 0.1250
# Epoch 231/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1513 - val_loss: 0.1667 - learning_rate: 0.1250
# Epoch 232/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1349 - val_loss: 0.1711 - learning_rate: 0.1250
# Epoch 233/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1405 - val_loss: 0.1717 - learning_rate: 0.1250
# Epoch 234/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1292 - val_loss: 0.1654 - learning_rate: 0.1250
# Epoch 235/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1318 - val_loss: 0.1649 - learning_rate: 0.1250
# Epoch 236/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1320 - val_loss: 0.1608 - learning_rate: 0.1250
# Epoch 237/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1352 - val_loss: 0.1706 - learning_rate: 0.1250
# Epoch 238/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1240 - val_loss: 0.1667 - learning_rate: 0.1250
# Epoch 239/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1291 - val_loss: 0.1715 - learning_rate: 0.1250
# Epoch 240/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1330 - val_loss: 0.1696 - learning_rate: 0.1250
# Epoch 241/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1335 - val_loss: 0.1682 - learning_rate: 0.1250
# Epoch 242/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1347 - val_loss: 0.1632 - learning_rate: 0.1250
# Epoch 243/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1268 - val_loss: 0.1680 - learning_rate: 0.1250
# Epoch 244/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1194 - val_loss: 0.1677 - learning_rate: 0.1250
# Epoch 245/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1236 - val_loss: 0.1637 - learning_rate: 0.1250
# Epoch 246/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1237
# Epoch 246: ReduceLROnPlateau reducing learning rate to 0.0625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1278 - val_loss: 0.1666 - learning_rate: 0.1250
# Epoch 247/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1416 - val_loss: 0.1602 - learning_rate: 0.0625
# Epoch 248/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1290 - val_loss: 0.1607 - learning_rate: 0.0625
# Epoch 249/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1181 - val_loss: 0.1621 - learning_rate: 0.0625
# Epoch 250/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1297 - val_loss: 0.1622 - learning_rate: 0.0625
# Epoch 251/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1284 - val_loss: 0.1636 - learning_rate: 0.0625
# Epoch 252/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1281 - val_loss: 0.1617 - learning_rate: 0.0625
# Epoch 253/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1309 - val_loss: 0.1605 - learning_rate: 0.0625
# Epoch 254/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1269 - val_loss: 0.1587 - learning_rate: 0.0625
# Epoch 255/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1243 - val_loss: 0.1617 - learning_rate: 0.0625
# Epoch 256/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1267 - val_loss: 0.1597 - learning_rate: 0.0625
# Epoch 257/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1150 - val_loss: 0.1618 - learning_rate: 0.0625
# Epoch 258/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1219 - val_loss: 0.1590 - learning_rate: 0.0625
# Epoch 259/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1225 - val_loss: 0.1599 - learning_rate: 0.0625
# Epoch 260/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1312 - val_loss: 0.1611 - learning_rate: 0.0625
# Epoch 261/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1330 - val_loss: 0.1552 - learning_rate: 0.0625
# Epoch 262/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1281 - val_loss: 0.1564 - learning_rate: 0.0625
# Epoch 263/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1317 - val_loss: 0.1552 - learning_rate: 0.0625
# Epoch 264/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1161 - val_loss: 0.1586 - learning_rate: 0.0625
# Epoch 265/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1271 - val_loss: 0.1573 - learning_rate: 0.0625
# Epoch 266/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1209 - val_loss: 0.1570 - learning_rate: 0.0625
# Epoch 267/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1254 - val_loss: 0.1589 - learning_rate: 0.0625
# Epoch 268/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1197 - val_loss: 0.1580 - learning_rate: 0.0625
# Epoch 269/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1312 - val_loss: 0.1574 - learning_rate: 0.0625
# Epoch 270/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1173 - val_loss: 0.1553 - learning_rate: 0.0625
# Epoch 271/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1369
# Epoch 271: ReduceLROnPlateau reducing learning rate to 0.03125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1269 - val_loss: 0.1576 - learning_rate: 0.0625
# Epoch 272/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1422 - val_loss: 0.1563 - learning_rate: 0.0312
# Epoch 273/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1202 - val_loss: 0.1562 - learning_rate: 0.0312
# Epoch 274/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1216 - val_loss: 0.1544 - learning_rate: 0.0312
# Epoch 275/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1252 - val_loss: 0.1544 - learning_rate: 0.0312
# Epoch 276/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1202 - val_loss: 0.1528 - learning_rate: 0.0312
# Epoch 277/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1192 - val_loss: 0.1524 - learning_rate: 0.0312
# Epoch 278/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1285 - val_loss: 0.1511 - learning_rate: 0.0312
# Epoch 279/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1132 - val_loss: 0.1486 - learning_rate: 0.0312
# Epoch 280/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1135 - val_loss: 0.1498 - learning_rate: 0.0312
# Epoch 281/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1195 - val_loss: 0.1474 - learning_rate: 0.0312
# Epoch 282/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1181 - val_loss: 0.1471 - learning_rate: 0.0312
# Epoch 283/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1141 - val_loss: 0.1478 - learning_rate: 0.0312
# Epoch 284/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1187 - val_loss: 0.1480 - learning_rate: 0.0312
# Epoch 285/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1180 - val_loss: 0.1459 - learning_rate: 0.0312
# Epoch 286/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1236 - val_loss: 0.1469 - learning_rate: 0.0312
# Epoch 287/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1227 - val_loss: 0.1489 - learning_rate: 0.0312
# Epoch 288/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1162 - val_loss: 0.1493 - learning_rate: 0.0312
# Epoch 289/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1227 - val_loss: 0.1478 - learning_rate: 0.0312
# Epoch 290/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1144 - val_loss: 0.1469 - learning_rate: 0.0312
# Epoch 291/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1197 - val_loss: 0.1465 - learning_rate: 0.0312
# Epoch 292/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1201 - val_loss: 0.1448 - learning_rate: 0.0312
# Epoch 293/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1179 - val_loss: 0.1454 - learning_rate: 0.0312
# Epoch 294/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1232 - val_loss: 0.1457 - learning_rate: 0.0312
# Epoch 295/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1135 - val_loss: 0.1462 - learning_rate: 0.0312
# Epoch 296/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1112 - val_loss: 0.1458 - learning_rate: 0.0312
# Epoch 297/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1275 - val_loss: 0.1469 - learning_rate: 0.0312
# Epoch 298/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1222 - val_loss: 0.1461 - learning_rate: 0.0312
# Epoch 299/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1155 - val_loss: 0.1453 - learning_rate: 0.0312
# Epoch 300/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1096 - val_loss: 0.1454 - learning_rate: 0.0312
# Epoch 301/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1191 - val_loss: 0.1439 - learning_rate: 0.0312
# Epoch 302/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1112 - val_loss: 0.1446 - learning_rate: 0.0312
# Epoch 303/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1208 - val_loss: 0.1472 - learning_rate: 0.0312
# Epoch 304/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1151 - val_loss: 0.1466 - learning_rate: 0.0312
# Epoch 305/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1306 - val_loss: 0.1461 - learning_rate: 0.0312
# Epoch 306/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1215 - val_loss: 0.1462 - learning_rate: 0.0312
# Epoch 307/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1119 - val_loss: 0.1459 - learning_rate: 0.0312
# Epoch 308/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1312 - val_loss: 0.1452 - learning_rate: 0.0312
# Epoch 309/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1250 - val_loss: 0.1466 - learning_rate: 0.0312
# Epoch 310/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1214 - val_loss: 0.1451 - learning_rate: 0.0312
# Epoch 311/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1160
# Epoch 311: ReduceLROnPlateau reducing learning rate to 0.015625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1219 - val_loss: 0.1439 - learning_rate: 0.0312
# Epoch 312/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1135 - val_loss: 0.1437 - learning_rate: 0.0156
# Epoch 313/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1155 - val_loss: 0.1436 - learning_rate: 0.0156
# Epoch 314/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1179 - val_loss: 0.1436 - learning_rate: 0.0156
# Epoch 315/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1208 - val_loss: 0.1438 - learning_rate: 0.0156
# Epoch 316/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1165 - val_loss: 0.1438 - learning_rate: 0.0156
# Epoch 317/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1132 - val_loss: 0.1432 - learning_rate: 0.0156
# Epoch 318/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1229 - val_loss: 0.1427 - learning_rate: 0.0156
# Epoch 319/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1103 - val_loss: 0.1427 - learning_rate: 0.0156
# Epoch 320/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1170 - val_loss: 0.1423 - learning_rate: 0.0156
# Epoch 321/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1160 - val_loss: 0.1417 - learning_rate: 0.0156
# Epoch 322/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1139 - val_loss: 0.1408 - learning_rate: 0.0156
# Epoch 323/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1063 - val_loss: 0.1408 - learning_rate: 0.0156
# Epoch 324/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1142 - val_loss: 0.1411 - learning_rate: 0.0156
# Epoch 325/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1052 - val_loss: 0.1412 - learning_rate: 0.0156
# Epoch 326/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1153 - val_loss: 0.1406 - learning_rate: 0.0156
# Epoch 327/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1101 - val_loss: 0.1406 - learning_rate: 0.0156
# Epoch 328/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1181 - val_loss: 0.1417 - learning_rate: 0.0156
# Epoch 329/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1124 - val_loss: 0.1425 - learning_rate: 0.0156
# Epoch 330/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1121 - val_loss: 0.1422 - learning_rate: 0.0156
# Epoch 331/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1170 - val_loss: 0.1422 - learning_rate: 0.0156
# Epoch 332/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1133 - val_loss: 0.1422 - learning_rate: 0.0156
# Epoch 333/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1242 - val_loss: 0.1430 - learning_rate: 0.0156
# Epoch 334/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1100 - val_loss: 0.1431 - learning_rate: 0.0156
# Epoch 335/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1296 - val_loss: 0.1422 - learning_rate: 0.0156
# Epoch 336/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1075
# Epoch 336: ReduceLROnPlateau reducing learning rate to 0.0078125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1147 - val_loss: 0.1422 - learning_rate: 0.0156
# Epoch 337/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1239 - val_loss: 0.1422 - learning_rate: 0.0078
# Epoch 338/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1235 - val_loss: 0.1422 - learning_rate: 0.0078
# Epoch 339/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1130 - val_loss: 0.1417 - learning_rate: 0.0078
# Epoch 340/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1119 - val_loss: 0.1417 - learning_rate: 0.0078
# Epoch 341/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1203 - val_loss: 0.1420 - learning_rate: 0.0078
# Epoch 342/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1166 - val_loss: 0.1420 - learning_rate: 0.0078
# Epoch 343/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1216 - val_loss: 0.1419 - learning_rate: 0.0078
# Epoch 344/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1154 - val_loss: 0.1414 - learning_rate: 0.0078
# Epoch 345/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1209 - val_loss: 0.1410 - learning_rate: 0.0078
# Epoch 346/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1075
# Epoch 346: ReduceLROnPlateau reducing learning rate to 0.00390625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1192 - val_loss: 0.1411 - learning_rate: 0.0078
# Epoch 347/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1147 - val_loss: 0.1414 - learning_rate: 0.0039
# Epoch 348/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1171 - val_loss: 0.1415 - learning_rate: 0.0039
# Epoch 349/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1088 - val_loss: 0.1417 - learning_rate: 0.0039
# Epoch 350/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1146 - val_loss: 0.1415 - learning_rate: 0.0039
# Epoch 351/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1206 - val_loss: 0.1415 - learning_rate: 0.0039
# Epoch 352/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1090 - val_loss: 0.1415 - learning_rate: 0.0039
# Epoch 353/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1193 - val_loss: 0.1414 - learning_rate: 0.0039
# Epoch 354/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1190 - val_loss: 0.1414 - learning_rate: 0.0039
# Epoch 355/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1125 - val_loss: 0.1415 - learning_rate: 0.0039
# Epoch 356/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0924
# Epoch 356: ReduceLROnPlateau reducing learning rate to 0.001953125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1078 - val_loss: 0.1414 - learning_rate: 0.0039
# Epoch 357/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1165 - val_loss: 0.1413 - learning_rate: 0.0020
# Epoch 358/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1214 - val_loss: 0.1411 - learning_rate: 0.0020
# Epoch 359/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1150 - val_loss: 0.1410 - learning_rate: 0.0020
# Epoch 360/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1163 - val_loss: 0.1409 - learning_rate: 0.0020
# Epoch 361/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1098 - val_loss: 0.1406 - learning_rate: 0.0020
# Epoch 362/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1137 - val_loss: 0.1405 - learning_rate: 0.0020
# Epoch 363/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1070 - val_loss: 0.1404 - learning_rate: 0.0020
# Epoch 364/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1127 - val_loss: 0.1404 - learning_rate: 0.0020
# Epoch 365/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1065 - val_loss: 0.1404 - learning_rate: 0.0020
# Epoch 366/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1106 - val_loss: 0.1404 - learning_rate: 0.0020
# Epoch 367/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1095 - val_loss: 0.1404 - learning_rate: 0.0020
# Epoch 368/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1227 - val_loss: 0.1405 - learning_rate: 0.0020
# Epoch 369/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1046 - val_loss: 0.1405 - learning_rate: 0.0020
# Epoch 370/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1123 - val_loss: 0.1404 - learning_rate: 0.0020
# Epoch 371/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1247 - val_loss: 0.1402 - learning_rate: 0.0020
# Epoch 372/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1103 - val_loss: 0.1403 - learning_rate: 0.0020
# Epoch 373/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1325 - val_loss: 0.1402 - learning_rate: 0.0020
# Epoch 374/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1153 - val_loss: 0.1400 - learning_rate: 0.0020
# Epoch 375/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1240 - val_loss: 0.1397 - learning_rate: 0.0020
# Epoch 376/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1111 - val_loss: 0.1397 - learning_rate: 0.0020
# Epoch 377/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1112 - val_loss: 0.1395 - learning_rate: 0.0020
# Epoch 378/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1227 - val_loss: 0.1395 - learning_rate: 0.0020
# Epoch 379/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1163 - val_loss: 0.1395 - learning_rate: 0.0020
# Epoch 380/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1124 - val_loss: 0.1396 - learning_rate: 0.0020
# Epoch 381/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1143 - val_loss: 0.1394 - learning_rate: 0.0020
# Epoch 382/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1134 - val_loss: 0.1394 - learning_rate: 0.0020
# Epoch 383/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1203 - val_loss: 0.1395 - learning_rate: 0.0020
# Epoch 384/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1197 - val_loss: 0.1394 - learning_rate: 0.0020
# Epoch 385/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1108 - val_loss: 0.1391 - learning_rate: 0.0020
# Epoch 386/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1256 - val_loss: 0.1393 - learning_rate: 0.0020
# Epoch 387/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1134 - val_loss: 0.1394 - learning_rate: 0.0020
# Epoch 388/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1103 - val_loss: 0.1395 - learning_rate: 0.0020
# Epoch 389/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1109 - val_loss: 0.1396 - learning_rate: 0.0020
# Epoch 390/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1215 - val_loss: 0.1396 - learning_rate: 0.0020
# Epoch 391/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1191 - val_loss: 0.1397 - learning_rate: 0.0020
# Epoch 392/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1050 - val_loss: 0.1396 - learning_rate: 0.0020
# Epoch 393/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1243 - val_loss: 0.1394 - learning_rate: 0.0020
# Epoch 394/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1106 - val_loss: 0.1393 - learning_rate: 0.0020
# Epoch 395/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1021 - val_loss: 0.1390 - learning_rate: 0.0020
# Epoch 396/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1150 - val_loss: 0.1391 - learning_rate: 0.0020
# Epoch 397/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1221 - val_loss: 0.1392 - learning_rate: 0.0020
# Epoch 398/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1136 - val_loss: 0.1392 - learning_rate: 0.0020
# Epoch 399/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1145 - val_loss: 0.1391 - learning_rate: 0.0020
# Epoch 400/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1112 - val_loss: 0.1392 - learning_rate: 0.0020
# Epoch 401/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1078 - val_loss: 0.1392 - learning_rate: 0.0020
# Epoch 402/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1165 - val_loss: 0.1393 - learning_rate: 0.0020
# Epoch 403/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1202 - val_loss: 0.1393 - learning_rate: 0.0020
# Epoch 404/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1146 - val_loss: 0.1392 - learning_rate: 0.0020
# Epoch 405/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1066
# Epoch 405: ReduceLROnPlateau reducing learning rate to 0.0009765625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1120 - val_loss: 0.1391 - learning_rate: 0.0020
# Epoch 406/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1183 - val_loss: 0.1393 - learning_rate: 9.7656e-04
# Epoch 407/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1190 - val_loss: 0.1392 - learning_rate: 9.7656e-04
# Epoch 408/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1079 - val_loss: 0.1392 - learning_rate: 9.7656e-04
# Epoch 409/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1206 - val_loss: 0.1394 - learning_rate: 9.7656e-04
# Epoch 410/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1158 - val_loss: 0.1393 - learning_rate: 9.7656e-04
# Epoch 411/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1228 - val_loss: 0.1393 - learning_rate: 9.7656e-04
# Epoch 412/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1124 - val_loss: 0.1393 - learning_rate: 9.7656e-04
# Epoch 413/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1095 - val_loss: 0.1391 - learning_rate: 9.7656e-04
# Epoch 414/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1132 - val_loss: 0.1392 - learning_rate: 9.7656e-04
# Epoch 415/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1341
# Epoch 415: ReduceLROnPlateau reducing learning rate to 0.00048828125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1220 - val_loss: 0.1391 - learning_rate: 9.7656e-04
# Epoch 416/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1112 - val_loss: 0.1390 - learning_rate: 4.8828e-04
# Epoch 417/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1171 - val_loss: 0.1389 - learning_rate: 4.8828e-04
# Epoch 418/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1172 - val_loss: 0.1390 - learning_rate: 4.8828e-04
# Epoch 419/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1241 - val_loss: 0.1388 - learning_rate: 4.8828e-04
# Epoch 420/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1133 - val_loss: 0.1388 - learning_rate: 4.8828e-04
# Epoch 421/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1101 - val_loss: 0.1389 - learning_rate: 4.8828e-04
# Epoch 422/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1102 - val_loss: 0.1388 - learning_rate: 4.8828e-04
# Epoch 423/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1225 - val_loss: 0.1388 - learning_rate: 4.8828e-04
# Epoch 424/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1175 - val_loss: 0.1390 - learning_rate: 4.8828e-04
# Epoch 425/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1136 - val_loss: 0.1389 - learning_rate: 4.8828e-04
# Epoch 426/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1099 - val_loss: 0.1387 - learning_rate: 4.8828e-04
# Epoch 427/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1173 - val_loss: 0.1386 - learning_rate: 4.8828e-04
# Epoch 428/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1092 - val_loss: 0.1384 - learning_rate: 4.8828e-04
# Epoch 429/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1107 - val_loss: 0.1382 - learning_rate: 4.8828e-04
# Epoch 430/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1137 - val_loss: 0.1384 - learning_rate: 4.8828e-04
# Epoch 431/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1133 - val_loss: 0.1383 - learning_rate: 4.8828e-04
# Epoch 432/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1119 - val_loss: 0.1384 - learning_rate: 4.8828e-04
# Epoch 433/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1196 - val_loss: 0.1387 - learning_rate: 4.8828e-04
# Epoch 434/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1130 - val_loss: 0.1387 - learning_rate: 4.8828e-04
# Epoch 435/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1156 - val_loss: 0.1388 - learning_rate: 4.8828e-04
# Epoch 436/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1165 - val_loss: 0.1388 - learning_rate: 4.8828e-04
# Epoch 437/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1114 - val_loss: 0.1390 - learning_rate: 4.8828e-04
# Epoch 438/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1090 - val_loss: 0.1391 - learning_rate: 4.8828e-04
# Epoch 439/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1148
# Epoch 439: ReduceLROnPlateau reducing learning rate to 0.000244140625.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1103 - val_loss: 0.1393 - learning_rate: 4.8828e-04
# Epoch 440/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1113 - val_loss: 0.1392 - learning_rate: 2.4414e-04
# Epoch 441/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1087 - val_loss: 0.1392 - learning_rate: 2.4414e-04
# Epoch 442/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1137 - val_loss: 0.1390 - learning_rate: 2.4414e-04
# Epoch 443/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1210 - val_loss: 0.1390 - learning_rate: 2.4414e-04
# Epoch 444/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1160 - val_loss: 0.1391 - learning_rate: 2.4414e-04
# Epoch 445/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1069 - val_loss: 0.1391 - learning_rate: 2.4414e-04
# Epoch 446/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1109 - val_loss: 0.1391 - learning_rate: 2.4414e-04
# Epoch 447/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1131 - val_loss: 0.1392 - learning_rate: 2.4414e-04
# Epoch 448/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1097 - val_loss: 0.1390 - learning_rate: 2.4414e-04
# Epoch 449/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1156
# Epoch 449: ReduceLROnPlateau reducing learning rate to 0.0001220703125.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1136 - val_loss: 0.1390 - learning_rate: 2.4414e-04
# Epoch 450/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1162 - val_loss: 0.1390 - learning_rate: 1.2207e-04
# Epoch 451/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1066 - val_loss: 0.1391 - learning_rate: 1.2207e-04
# Epoch 452/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1157 - val_loss: 0.1392 - learning_rate: 1.2207e-04
# Epoch 453/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1162 - val_loss: 0.1392 - learning_rate: 1.2207e-04
# Epoch 454/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1122 - val_loss: 0.1392 - learning_rate: 1.2207e-04
# Epoch 455/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1186 - val_loss: 0.1394 - learning_rate: 1.2207e-04
# Epoch 456/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1058 - val_loss: 0.1393 - learning_rate: 1.2207e-04
# Epoch 457/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1145 - val_loss: 0.1394 - learning_rate: 1.2207e-04
# Epoch 458/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1143 - val_loss: 0.1393 - learning_rate: 1.2207e-04
# Epoch 459/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1111
# Epoch 459: ReduceLROnPlateau reducing learning rate to 6.103515625e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1109 - val_loss: 0.1395 - learning_rate: 1.2207e-04
# Epoch 460/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1223 - val_loss: 0.1395 - learning_rate: 6.1035e-05
# Epoch 461/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1155 - val_loss: 0.1393 - learning_rate: 6.1035e-05
# Epoch 462/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1096 - val_loss: 0.1393 - learning_rate: 6.1035e-05
# Epoch 463/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1154 - val_loss: 0.1394 - learning_rate: 6.1035e-05
# Epoch 464/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1160 - val_loss: 0.1392 - learning_rate: 6.1035e-05
# Epoch 465/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1118 - val_loss: 0.1387 - learning_rate: 6.1035e-05
# Epoch 466/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1166 - val_loss: 0.1386 - learning_rate: 6.1035e-05
# Epoch 467/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1132 - val_loss: 0.1387 - learning_rate: 6.1035e-05
# Epoch 468/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1085 - val_loss: 0.1388 - learning_rate: 6.1035e-05
# Epoch 469/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1092
# Epoch 469: ReduceLROnPlateau reducing learning rate to 3.0517578125e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1166 - val_loss: 0.1389 - learning_rate: 6.1035e-05
# Epoch 470/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1117 - val_loss: 0.1391 - learning_rate: 3.0518e-05
# Epoch 471/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1123 - val_loss: 0.1391 - learning_rate: 3.0518e-05
# Epoch 472/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1229 - val_loss: 0.1392 - learning_rate: 3.0518e-05
# Epoch 473/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1136 - val_loss: 0.1392 - learning_rate: 3.0518e-05
# Epoch 474/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1142 - val_loss: 0.1394 - learning_rate: 3.0518e-05
# Epoch 475/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1133 - val_loss: 0.1395 - learning_rate: 3.0518e-05
# Epoch 476/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1175 - val_loss: 0.1396 - learning_rate: 3.0518e-05
# Epoch 477/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1154 - val_loss: 0.1394 - learning_rate: 3.0518e-05
# Epoch 478/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1121 - val_loss: 0.1392 - learning_rate: 3.0518e-05
# Epoch 479/1000
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1167
# Epoch 479: ReduceLROnPlateau reducing learning rate to 1.52587890625e-05.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1189 - val_loss: 0.1393 - learning_rate: 3.0518e-05
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# Training R2 Score: 0.7839916013695867
# Testing R2 Score: 0.6576600207913385
# Training Mean Absolute Error: 0.06751218123822593
# Testing Mean Absolute Error: 0.09954577953596801
